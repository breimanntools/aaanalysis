# %% [markdown]
# # `AAWindowSampler.sample_synthetic()`
#
# Generate synthetic control windows from a configurable amino-acid prior. Useful as a third-distribution control alongside `sample_same_protein` (negatives) and `sample_different_protein` (unlabeled). Synthetic windows have no source protein, so `output_mode` is fixed to `'segments'`.

# %%
import aaanalysis as aa
import pandas as pd
aa.options["verbose"] = False

df_seq = pd.DataFrame({
    "entry":    ["P1", "P2"],
    "sequence": ["ACDEFGHIKLMNPQRSTVWY" * 2,
                 "YWVTSRQPNMLKIHGFEDCA" * 2],
    "pos":      [[10], [15]],
})
aaws = aa.AAWindowSampler(random_state=0)

# %% [markdown]
# First call — anchor schema. The eight-column `segments` schema is shared across all `AAWindowSampler` methods; synthetic rows use `entry_win = synth_{i}` and leave `entry` empty since there is no source protein.

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=5, window_size=9, seed=0)
aa.display_df(df=df, show_shape=True)
# Out:
# DataFrame shape: (5, 8)
# <style type="text/css">
# #T_0a7b6 thead th {
#   background-color: white;
#   color: black;
# }
# #T_0a7b6 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_0a7b6 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_0a7b6 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_0a7b6  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_0a7b6" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a7b6_level0_col0" class="col_heading level0 col0" >entry_win</th>
#       <th id="T_0a7b6_level0_col1" class="col_heading level0 col1" >entry</th>
#       <th id="T_0a7b6_level0_col2" class="col_heading level0 col2" >sequence</th>
#       <th id="T_0a7b6_level0_col3" class="col_heading level0 col3" >window</th>
#       <th id="T_0a7b6_level0_col4" class="col_heading level0 col4" >source_position</th>
#       <th id="T_0a7b6_level0_col5" class="col_heading level0 col5" >label</th>
#       <th id="T_0a7b6_level0_col6" class="col_heading level0 col6" >role</th>
#       <th id="T_0a7b6_level0_col7" class="col_heading level0 col7" >strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a7b6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0a7b6_row0_col0" class="data row0 col0" >synth_0</td>
#       <td id="T_0a7b6_row0_col1" class="data row0 col1" ></td>
#       <td id="T_0a7b6_row0_col2" class="data row0 col2" ></td>
#       <td id="T_0a7b6_row0_col3" class="data row0 col3" >PGAATWPRM</td>
#       <td id="T_0a7b6_row0_col4" class="data row0 col4" >-1</td>
#       <td id="T_0a7b6_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_0a7b6_row0_col6" class="data row0 col6" >Control</td>
#       <td id="T_0a7b6_row0_col7" class="data row0 col7" >synthetic:global_freq</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0a7b6_row1_col0" class="data row1 col0" >synth_1</td>
#       <td id="T_0a7b6_row1_col1" class="data row1 col1" ></td>
#       <td id="T_0a7b6_row1_col2" class="data row1 col2" ></td>
#       <td id="T_0a7b6_row1_col3" class="data row1 col3" >WTAVAREVM</td>
#       <td id="T_0a7b6_row1_col4" class="data row1 col4" >-1</td>
#       <td id="T_0a7b6_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_0a7b6_row1_col6" class="data row1 col6" >Control</td>
#       <td id="T_0a7b6_row1_col7" class="data row1 col7" >synthetic:global_freq</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_0a7b6_row2_col0" class="data row2 col0" >synth_2</td>
#       <td id="T_0a7b6_row2_col1" class="data row2 col1" ></td>
#       <td id="T_0a7b6_row2_col2" class="data row2 col2" ></td>
#       <td id="T_0a7b6_row2_col3" class="data row2 col3" >GKADQPPIY</td>
#       <td id="T_0a7b6_row2_col4" class="data row2 col4" >-1</td>
#       <td id="T_0a7b6_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_0a7b6_row2_col6" class="data row2 col6" >Control</td>
#       <td id="T_0a7b6_row2_col7" class="data row2 col7" >synthetic:global_freq</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_0a7b6_row3_col0" class="data row3 col0" >synth_3</td>
#       <td id="T_0a7b6_row3_col1" class="data row3 col1" ></td>
#       <td id="T_0a7b6_row3_col2" class="data row3 col2" ></td>
#       <td id="T_0a7b6_row3_col3" class="data row3 col3" >YQQQIDRMH</td>
#       <td id="T_0a7b6_row3_col4" class="data row3 col4" >-1</td>
#       <td id="T_0a7b6_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_0a7b6_row3_col6" class="data row3 col6" >Control</td>
#       <td id="T_0a7b6_row3_col7" class="data row3 col7" >synthetic:global_freq</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_0a7b6_row4_col0" class="data row4 col0" >synth_4</td>
#       <td id="T_0a7b6_row4_col1" class="data row4 col1" ></td>
#       <td id="T_0a7b6_row4_col2" class="data row4 col2" ></td>
#       <td id="T_0a7b6_row4_col3" class="data row4 col3" >LVWINHNHI</td>
#       <td id="T_0a7b6_row4_col4" class="data row4 col4" >-1</td>
#       <td id="T_0a7b6_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_0a7b6_row4_col6" class="data row4 col6" >Control</td>
#       <td id="T_0a7b6_row4_col7" class="data row4 col7" >synthetic:global_freq</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `df_seq`, `pos_col`
#
# `df_seq` is consumed differently per generator — see the `generator` section below. `pos_col` is required only for the `'position_specific'` and `'scrambled'` generators (which read test windows from the positions in `pos_col`). For all other generators, `pos_col` is optional and is used only as the source of test windows for the anti-leakage filter.

# %% [markdown]
# ## `n`, `window_size`
#
# Total number of synthetic windows (`n`) and residue length per window (`window_size`):

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=12,
                              generator="global_freq", seed=0)
aa.display_df(df=df[["entry_win", "window"]], show_shape=True)
# Out:
# DataFrame shape: (3, 2)
# <style type="text/css">
# #T_5e20b thead th {
#   background-color: white;
#   color: black;
# }
# #T_5e20b tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_5e20b tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_5e20b th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_5e20b  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_5e20b" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e20b_level0_col0" class="col_heading level0 col0" >entry_win</th>
#       <th id="T_5e20b_level0_col1" class="col_heading level0 col1" >window</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e20b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5e20b_row0_col0" class="data row0 col0" >synth_0</td>
#       <td id="T_5e20b_row0_col1" class="data row0 col1" >PGAATWPRMWTA</td>
#     </tr>
#     <tr>
#       <th id="T_5e20b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5e20b_row1_col0" class="data row1 col0" >synth_1</td>
#       <td id="T_5e20b_row1_col1" class="data row1 col1" >VAREVMGKADQP</td>
#     </tr>
#     <tr>
#       <th id="T_5e20b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5e20b_row2_col0" class="data row2 col0" >synth_2</td>
#       <td id="T_5e20b_row2_col1" class="data row2 col1" >PIYYQQQIDRMH</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `generator`
#
# The synthesis recipe. Accepts three shapes:
#
# - `str` — a built-in generator (`'uniform'`, `'global_freq'`, `'position_specific'`, `'scrambled'`) or an AAontology preset name (e.g. `'aa_composition'`, `'alpha_helix'`).
# - `list[str]` — at least two distinct preset names; their per-AA priors are combined into a multiplicative joint prior.
# - `dict[str, float]` — a custom single-character → probability table. Keys define the alphabet, so the sampler is not restricted to amino acids.
#
# **Built-in generators** draw uniformly over the canonical 20 (`'uniform'`), from the empirical AA frequency in `df_seq` (`'global_freq'`), per-position in the test windows (`'position_specific'`), or by shuffling a test window (`'scrambled'`):

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                              generator="global_freq", seed=0)
aa.display_df(df=df[["window", "strategy"]], show_shape=True)
# Out:
# DataFrame shape: (3, 2)
# <style type="text/css">
# #T_5fa28 thead th {
#   background-color: white;
#   color: black;
# }
# #T_5fa28 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_5fa28 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_5fa28 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_5fa28  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_5fa28" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fa28_level0_col0" class="col_heading level0 col0" >window</th>
#       <th id="T_5fa28_level0_col1" class="col_heading level0 col1" >strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fa28_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5fa28_row0_col0" class="data row0 col0" >PGAATWPRM</td>
#       <td id="T_5fa28_row0_col1" class="data row0 col1" >synthetic:global_freq</td>
#     </tr>
#     <tr>
#       <th id="T_5fa28_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5fa28_row1_col0" class="data row1 col0" >WTAVAREVM</td>
#       <td id="T_5fa28_row1_col1" class="data row1 col1" >synthetic:global_freq</td>
#     </tr>
#     <tr>
#       <th id="T_5fa28_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5fa28_row2_col0" class="data row2 col0" >GKADQPPIY</td>
#       <td id="T_5fa28_row2_col1" class="data row2 col1" >synthetic:global_freq</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **AAontology preset generators** use a curated scale as the per-AA prior. Composition presets (`'aa_composition'`, `'aa_composition_surface'`, `'aa_composition_mp'`) are true AA-frequency distributions; conformation presets (`'alpha_helix'`, `'beta_sheet'`, `'beta_strand'`, `'beta_turn'`, `'coil'`, `'linker'`, `'pi_helix'`) are normalized propensities used as physicochemically-biased priors:

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                              generator="alpha_helix", seed=0)
aa.display_df(df=df[["window", "strategy"]], show_shape=True)
# Out:
# DataFrame shape: (3, 2)
# <style type="text/css">
# #T_6aa5c thead th {
#   background-color: white;
#   color: black;
# }
# #T_6aa5c tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_6aa5c tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_6aa5c th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_6aa5c  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_6aa5c" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6aa5c_level0_col0" class="col_heading level0 col0" >window</th>
#       <th id="T_6aa5c_level0_col1" class="col_heading level0 col1" >strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa5c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6aa5c_row0_col0" class="data row0 col0" >NFAASWMQM</td>
#       <td id="T_6aa5c_row0_col1" class="data row0 col1" >synthetic:alpha_helix</td>
#     </tr>
#     <tr>
#       <th id="T_6aa5c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6aa5c_row1_col0" class="data row1 col0" >WSATAREVM</td>
#       <td id="T_6aa5c_row1_col1" class="data row1 col1" >synthetic:alpha_helix</td>
#     </tr>
#     <tr>
#       <th id="T_6aa5c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6aa5c_row2_col0" class="data row2 col0" >GKADPPNIY</td>
#       <td id="T_6aa5c_row2_col1" class="data row2 col1" >synthetic:alpha_helix</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Mixed-prior generator** — a list of at least two distinct preset names combines their per-AA priors via element-wise product followed by renormalization. Useful e.g. for a membrane-helix prior (`['aa_composition_mp', 'alpha_helix']`):

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                              generator=["aa_composition_mp", "alpha_helix"], seed=0)
aa.display_df(df=df[["window", "strategy"]], show_shape=True)
# Out:
# DataFrame shape: (3, 2)
# <style type="text/css">
# #T_bf76c thead th {
#   background-color: white;
#   color: black;
# }
# #T_bf76c tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_bf76c tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_bf76c th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_bf76c  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_bf76c" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf76c_level0_col0" class="col_heading level0 col0" >window</th>
#       <th id="T_bf76c_level0_col1" class="col_heading level0 col1" >strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf76c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bf76c_row0_col0" class="data row0 col0" >MFAASVLQL</td>
#       <td id="T_bf76c_row0_col1" class="data row0 col1" >synthetic:mix:a..._mp+alpha_helix</td>
#     </tr>
#     <tr>
#       <th id="T_bf76c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bf76c_row1_col0" class="data row1 col0" >VSATAQETL</td>
#       <td id="T_bf76c_row1_col1" class="data row1 col1" >synthetic:mix:a..._mp+alpha_helix</td>
#     </tr>
#     <tr>
#       <th id="T_bf76c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bf76c_row2_col0" class="data row2 col0" >GIACNMMIY</td>
#       <td id="T_bf76c_row2_col1" class="data row2 col1" >synthetic:mix:a..._mp+alpha_helix</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Custom-alphabet generator** — a `dict[str, float]` over any single-character alphabet (e.g. DNA). The only generator path that produces non-amino-acid windows. Keys are case-sensitive and values must sum to 1.0 (within 1e-6):

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=8,
                              generator={"A": 0.25, "C": 0.25, "G": 0.25, "T": 0.25},
                              seed=0)
aa.display_df(df=df[["window", "strategy"]], show_shape=True)
# Out:
# DataFrame shape: (3, 2)
# <style type="text/css">
# #T_29ad8 thead th {
#   background-color: white;
#   color: black;
# }
# #T_29ad8 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_29ad8 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_29ad8 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_29ad8  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_29ad8" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29ad8_level0_col0" class="col_heading level0 col0" >window</th>
#       <th id="T_29ad8_level0_col1" class="col_heading level0 col1" >strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29ad8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_29ad8_row0_col0" class="data row0 col0" >GCAATTGG</td>
#       <td id="T_29ad8_row0_col1" class="data row0 col1" >synthetic:custom:A+C+G+T</td>
#     </tr>
#     <tr>
#       <th id="T_29ad8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_29ad8_row1_col0" class="data row1 col0" >GTTATAGA</td>
#       <td id="T_29ad8_row1_col1" class="data row1 col1" >synthetic:custom:A+C+G+T</td>
#     </tr>
#     <tr>
#       <th id="T_29ad8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_29ad8_row2_col0" class="data row2 col0" >TGCCAAGG</td>
#       <td id="T_29ad8_row2_col1" class="data row2 col1" >synthetic:custom:A+C+G+T</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `label_ref`, `role`
#
# Semantic tags applied to all synthetic rows. Defaults: `role='Control'`, `label_ref=0`. Override for non-PU-learning workflows:

# %%
df = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                              generator="global_freq",
                              role="background", label_ref=-1, seed=0)
aa.display_df(df=df[["window", "role", "label"]], show_shape=True)
# Out:
# DataFrame shape: (3, 3)
# <style type="text/css">
# #T_d5049 thead th {
#   background-color: white;
#   color: black;
# }
# #T_d5049 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_d5049 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_d5049 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_d5049  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_d5049" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5049_level0_col0" class="col_heading level0 col0" >window</th>
#       <th id="T_d5049_level0_col1" class="col_heading level0 col1" >role</th>
#       <th id="T_d5049_level0_col2" class="col_heading level0 col2" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5049_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d5049_row0_col0" class="data row0 col0" >PGAATWPRM</td>
#       <td id="T_d5049_row0_col1" class="data row0 col1" >background</td>
#       <td id="T_d5049_row0_col2" class="data row0 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d5049_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d5049_row1_col0" class="data row1 col0" >WTAVAREVM</td>
#       <td id="T_d5049_row1_col1" class="data row1 col1" >background</td>
#       <td id="T_d5049_row1_col2" class="data row1 col2" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d5049_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d5049_row2_col0" class="data row2 col0" >GKADQPPIY</td>
#       <td id="T_d5049_row2_col1" class="data row2 col1" >background</td>
#       <td id="T_d5049_row2_col2" class="data row2 col2" >-1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## `seed`
#
# Per-call seed; falls back to the class-level `random_state` set at construction. A fixed seed yields deterministic output:

# %%
df_a = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                                generator="global_freq", seed=42)
df_b = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                                generator="global_freq", seed=42)
print("deterministic:", list(df_a["window"]) == list(df_b["window"]))
# Out:
# deterministic: True

# %% [markdown]
# Synthetic outputs use `entry_win = synth_{i}` with a per-call counter — concatenating multiple `sample_synthetic` outputs may collide on `entry_win`. Deduplicate on the `window` column instead.

# %% [markdown]
# ## Further parameter: `pos_col`
#
# `pos_col` names the column of per-row 1-based positive positions. It is **required** for the `'position_specific'` and `'scrambled'` generators, which build their prior from the test windows extracted at those positions (for the other generators it is optional and only feeds the anti-leakage filter):

# %%
# pos_col drives the 'position_specific' generator (per-position freq of the test windows)
df_ps = aaws.sample_synthetic(df_seq=df_seq, n=3, window_size=9,
                              generator="position_specific", pos_col="pos", seed=0)
aa.display_df(df=df_ps[["window", "strategy"]], show_shape=True)
# Out:
# DataFrame shape: (3, 2)
# <style type="text/css">
# #T_b6efc thead th {
#   background-color: white;
#   color: black;
# }
# #T_b6efc tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_b6efc tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_b6efc th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_b6efc  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_b6efc" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6efc_level0_col0" class="col_heading level0 col0" >window</th>
#       <th id="T_b6efc_level0_col1" class="col_heading level0 col1" >strategy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6efc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b6efc_row0_col0" class="data row0 col0" >LHIHLMNPQ</td>
#       <td id="T_b6efc_row0_col1" class="data row0 col1" >synthetic:position_specific</td>
#     </tr>
#     <tr>
#       <th id="T_b6efc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b6efc_row1_col0" class="data row1 col0" >LKIKGMEPQ</td>
#       <td id="T_b6efc_row1_col1" class="data row1 col1" >synthetic:position_specific</td>
#     </tr>
#     <tr>
#       <th id="T_b6efc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b6efc_row2_col0" class="data row2 col0" >GHIHLMNDQ</td>
#       <td id="T_b6efc_row2_col1" class="data row2 col1" >synthetic:position_specific</td>
#     </tr>
#   </tbody>
# </table>
