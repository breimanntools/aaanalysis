# %% [markdown]
# :meth:`AAMut.eval` ranks scales by their mean absolute substitution delta — i.e. which physicochemical properties are most sensitive to amino acid changes.

# %%
import aaanalysis as aa
aam = aa.AAMut()
df_impact = aam.run(from_aa=["M", "L", "K"], to_aa=["V", "A", "D"])
aa.display_df(aam.eval(df_impact=df_impact), n_rows=10, show_shape=True)
# Out:
# DataFrame shape: (586, 2)
# <style type="text/css">
# #T_d8d2d thead th {
#   background-color: white;
#   color: black;
# }
# #T_d8d2d tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_d8d2d tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_d8d2d th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_d8d2d  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_d8d2d" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8d2d_level0_col0" class="col_heading level0 col0" >scale_id</th>
#       <th id="T_d8d2d_level0_col1" class="col_heading level0 col1" >mean_delta_cpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8d2d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d8d2d_row0_col0" class="data row0 col0" >CHAM830108</td>
#       <td id="T_d8d2d_row0_col1" class="data row0 col1" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d8d2d_row1_col0" class="data row1 col0" >NAKH900104</td>
#       <td id="T_d8d2d_row1_col1" class="data row1 col1" >0.578222</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d8d2d_row2_col0" class="data row2 col0" >NAKH900106</td>
#       <td id="T_d8d2d_row2_col1" class="data row2 col1" >0.574222</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d8d2d_row3_col0" class="data row3 col0" >ARGP820103</td>
#       <td id="T_d8d2d_row3_col1" class="data row3 col1" >0.567111</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d8d2d_row4_col0" class="data row4 col0" >ARGP820102</td>
#       <td id="T_d8d2d_row4_col1" class="data row4 col1" >0.532222</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d8d2d_row5_col0" class="data row5 col0" >RACS820103</td>
#       <td id="T_d8d2d_row5_col1" class="data row5 col1" >0.530667</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d8d2d_row6_col0" class="data row6 col0" >QIAN880126</td>
#       <td id="T_d8d2d_row6_col1" class="data row6 col1" >0.519667</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d8d2d_row7_col0" class="data row7 col0" >FUKS010107</td>
#       <td id="T_d8d2d_row7_col1" class="data row7 col1" >0.514667</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_d8d2d_row8_col0" class="data row8 col0" >CHAM830104</td>
#       <td id="T_d8d2d_row8_col1" class="data row8 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d8d2d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_d8d2d_row9_col0" class="data row9 col0" >PLIV810101</td>
#       <td id="T_d8d2d_row9_col1" class="data row9 col1" >0.497889</td>
#     </tr>
#   </tbody>
# </table>
