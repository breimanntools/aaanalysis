# %% [markdown]
# To demonstrate the ``ShapExplainer().add_sample_mean_dif()`` method, we obtain the DOM_GSEC example dataset and its respective feature set (see [Breimann24c]_):

# %%
import aaanalysis as aa
aa.options["verbose"] = False # Disable verbosity

df_seq = aa.load_dataset(name="DOM_GSEC", n=3)
labels = df_seq["label"].to_list()
df_feat = aa.load_features(name="DOM_GSEC").head(5)

# Create feature matrix
sf = aa.SequenceFeature()
df_parts = sf.get_df_parts(df_seq=df_seq)
X = sf.feature_matrix(features=df_feat["feature"], df_parts=df_parts)

aa.display_df(df_seq)
# Out:
# <style type="text/css">
# #T_bf400 thead th {
#   background-color: white;
#   color: black;
# }
# #T_bf400 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_bf400 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_bf400 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_bf400  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_bf400" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf400_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_bf400_level0_col1" class="col_heading level0 col1" >sequence</th>
#       <th id="T_bf400_level0_col2" class="col_heading level0 col2" >label</th>
#       <th id="T_bf400_level0_col3" class="col_heading level0 col3" >tmd_start</th>
#       <th id="T_bf400_level0_col4" class="col_heading level0 col4" >tmd_stop</th>
#       <th id="T_bf400_level0_col5" class="col_heading level0 col5" >jmd_n</th>
#       <th id="T_bf400_level0_col6" class="col_heading level0 col6" >tmd</th>
#       <th id="T_bf400_level0_col7" class="col_heading level0 col7" >jmd_c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf400_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bf400_row0_col0" class="data row0 col0" >Q14802</td>
#       <td id="T_bf400_row0_col1" class="data row0 col1" >MQKVTLGLLVFLAGF...PGETPPLITPGSAQS</td>
#       <td id="T_bf400_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_bf400_row0_col3" class="data row0 col3" >37</td>
#       <td id="T_bf400_row0_col4" class="data row0 col4" >59</td>
#       <td id="T_bf400_row0_col5" class="data row0 col5" >NSPFYYDWHS</td>
#       <td id="T_bf400_row0_col6" class="data row0 col6" >LQVGGLICAGVLCAMGIIIVMSA</td>
#       <td id="T_bf400_row0_col7" class="data row0 col7" >KCKCKFGQKS</td>
#     </tr>
#     <tr>
#       <th id="T_bf400_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bf400_row1_col0" class="data row1 col0" >Q86UE4</td>
#       <td id="T_bf400_row1_col1" class="data row1 col1" >MAARSWQDELAQQAE...SPKQIKKKKKARRET</td>
#       <td id="T_bf400_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_bf400_row1_col3" class="data row1 col3" >50</td>
#       <td id="T_bf400_row1_col4" class="data row1 col4" >72</td>
#       <td id="T_bf400_row1_col5" class="data row1 col5" >LGLEPKRYPG</td>
#       <td id="T_bf400_row1_col6" class="data row1 col6" >WVILVGTGALGLLLLFLLGYGWA</td>
#       <td id="T_bf400_row1_col7" class="data row1 col7" >AACAGARKKR</td>
#     </tr>
#     <tr>
#       <th id="T_bf400_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bf400_row2_col0" class="data row2 col0" >Q969W9</td>
#       <td id="T_bf400_row2_col1" class="data row2 col1" >MHRLMGVNSTAAAAA...AIWSKEKDKQKGHPL</td>
#       <td id="T_bf400_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_bf400_row2_col3" class="data row2 col3" >41</td>
#       <td id="T_bf400_row2_col4" class="data row2 col4" >63</td>
#       <td id="T_bf400_row2_col5" class="data row2 col5" >FQSMEITELE</td>
#       <td id="T_bf400_row2_col6" class="data row2 col6" >FVQIIIIVVVMMVMVVVITCLLS</td>
#       <td id="T_bf400_row2_col7" class="data row2 col7" >HYKLSARSFI</td>
#     </tr>
#     <tr>
#       <th id="T_bf400_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_bf400_row3_col0" class="data row3 col0" >P05067</td>
#       <td id="T_bf400_row3_col1" class="data row3 col1" >MLPGLALLLLAAWTA...GYENPTYKFFEQMQN</td>
#       <td id="T_bf400_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_bf400_row3_col3" class="data row3 col3" >701</td>
#       <td id="T_bf400_row3_col4" class="data row3 col4" >723</td>
#       <td id="T_bf400_row3_col5" class="data row3 col5" >FAEDVGSNKG</td>
#       <td id="T_bf400_row3_col6" class="data row3 col6" >AIIGLMVGGVVIATVIVITLVML</td>
#       <td id="T_bf400_row3_col7" class="data row3 col7" >KKKQYTSIHH</td>
#     </tr>
#     <tr>
#       <th id="T_bf400_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_bf400_row4_col0" class="data row4 col0" >P14925</td>
#       <td id="T_bf400_row4_col1" class="data row4 col1" >MAGRARSGLLLLLLG...EEEYSAPLPKPAPSS</td>
#       <td id="T_bf400_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_bf400_row4_col3" class="data row4 col3" >868</td>
#       <td id="T_bf400_row4_col4" class="data row4 col4" >890</td>
#       <td id="T_bf400_row4_col5" class="data row4 col5" >KLSTEPGSGV</td>
#       <td id="T_bf400_row4_col6" class="data row4 col6" >SVVLITTLLVIPVLVLLAIVMFI</td>
#       <td id="T_bf400_row4_col7" class="data row4 col7" >RWKKSRAFGD</td>
#     </tr>
#     <tr>
#       <th id="T_bf400_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_bf400_row5_col0" class="data row5 col0" >P70180</td>
#       <td id="T_bf400_row5_col1" class="data row5 col1" >MRSLLLFTFSACVLL...RELREDSIRSHFSVA</td>
#       <td id="T_bf400_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_bf400_row5_col3" class="data row5 col3" >477</td>
#       <td id="T_bf400_row5_col4" class="data row5 col4" >499</td>
#       <td id="T_bf400_row5_col5" class="data row5 col5" >PCKSSGGLEE</td>
#       <td id="T_bf400_row5_col6" class="data row5 col6" >SAVTGIVVGALLGAGLLMAFYFF</td>
#       <td id="T_bf400_row5_col7" class="data row5 col7" >RKKYRITIER</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You need to provide ``X``, ``labels``, and ``df_feat`` to the ``ShapExplainer().add_samples_mean_dif()`` method, which will then  compute the feature value difference for each sample against the reference group average:

# %%
se = aa.ShapExplainer()

# Compute difference against average for negative (0) group
df_feat = se.add_sample_mean_dif(X, labels=labels, df_feat=df_feat)
aa.display_df(df_feat)
# Out:
# <style type="text/css">
# #T_d4940 thead th {
#   background-color: white;
#   color: black;
# }
# #T_d4940 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_d4940 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_d4940 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_d4940  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_d4940" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4940_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_d4940_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_d4940_level0_col2" class="col_heading level0 col2" >subcategory</th>
#       <th id="T_d4940_level0_col3" class="col_heading level0 col3" >scale_name</th>
#       <th id="T_d4940_level0_col4" class="col_heading level0 col4" >scale_description</th>
#       <th id="T_d4940_level0_col5" class="col_heading level0 col5" >abs_auc</th>
#       <th id="T_d4940_level0_col6" class="col_heading level0 col6" >abs_mean_dif</th>
#       <th id="T_d4940_level0_col7" class="col_heading level0 col7" >mean_dif</th>
#       <th id="T_d4940_level0_col8" class="col_heading level0 col8" >std_test</th>
#       <th id="T_d4940_level0_col9" class="col_heading level0 col9" >std_ref</th>
#       <th id="T_d4940_level0_col10" class="col_heading level0 col10" >p_val_mann_whitney</th>
#       <th id="T_d4940_level0_col11" class="col_heading level0 col11" >p_val_fdr_bh</th>
#       <th id="T_d4940_level0_col12" class="col_heading level0 col12" >positions</th>
#       <th id="T_d4940_level0_col13" class="col_heading level0 col13" >feat_importance</th>
#       <th id="T_d4940_level0_col14" class="col_heading level0 col14" >feat_importance_std</th>
#       <th id="T_d4940_level0_col15" class="col_heading level0 col15" >mean_dif_Protein0</th>
#       <th id="T_d4940_level0_col16" class="col_heading level0 col16" >mean_dif_Protein1</th>
#       <th id="T_d4940_level0_col17" class="col_heading level0 col17" >mean_dif_Protein2</th>
#       <th id="T_d4940_level0_col18" class="col_heading level0 col18" >mean_dif_Protein3</th>
#       <th id="T_d4940_level0_col19" class="col_heading level0 col19" >mean_dif_Protein4</th>
#       <th id="T_d4940_level0_col20" class="col_heading level0 col20" >mean_dif_Protein5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4940_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d4940_row0_col0" class="data row0 col0" >TMD_C_JMD_C-Seg...3,4)-KLEP840101</td>
#       <td id="T_d4940_row0_col1" class="data row0 col1" >Energy</td>
#       <td id="T_d4940_row0_col2" class="data row0 col2" >Charge</td>
#       <td id="T_d4940_row0_col3" class="data row0 col3" >Charge</td>
#       <td id="T_d4940_row0_col4" class="data row0 col4" >Net charge (Kle...n et al., 1984)</td>
#       <td id="T_d4940_row0_col5" class="data row0 col5" >0.244000</td>
#       <td id="T_d4940_row0_col6" class="data row0 col6" >0.103666</td>
#       <td id="T_d4940_row0_col7" class="data row0 col7" >0.103666</td>
#       <td id="T_d4940_row0_col8" class="data row0 col8" >0.106692</td>
#       <td id="T_d4940_row0_col9" class="data row0 col9" >0.110506</td>
#       <td id="T_d4940_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_d4940_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_d4940_row0_col12" class="data row0 col12" >31,32,33,34,35</td>
#       <td id="T_d4940_row0_col13" class="data row0 col13" >0.970400</td>
#       <td id="T_d4940_row0_col14" class="data row0 col14" >1.438918</td>
#       <td id="T_d4940_row0_col15" class="data row0 col15" >0.100000</td>
#       <td id="T_d4940_row0_col16" class="data row0 col16" >-0.100000</td>
#       <td id="T_d4940_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_d4940_row0_col18" class="data row0 col18" >0.200000</td>
#       <td id="T_d4940_row0_col19" class="data row0 col19" >0.200000</td>
#       <td id="T_d4940_row0_col20" class="data row0 col20" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_d4940_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d4940_row1_col0" class="data row1 col0" >TMD_C_JMD_C-Seg...3,4)-FINA910104</td>
#       <td id="T_d4940_row1_col1" class="data row1 col1" >Conformation</td>
#       <td id="T_d4940_row1_col2" class="data row1 col2" >α-helix (C-cap)</td>
#       <td id="T_d4940_row1_col3" class="data row1 col3" >α-helix termination</td>
#       <td id="T_d4940_row1_col4" class="data row1 col4" >Helix terminati...n et al., 1991)</td>
#       <td id="T_d4940_row1_col5" class="data row1 col5" >0.243000</td>
#       <td id="T_d4940_row1_col6" class="data row1 col6" >0.085064</td>
#       <td id="T_d4940_row1_col7" class="data row1 col7" >0.085064</td>
#       <td id="T_d4940_row1_col8" class="data row1 col8" >0.098774</td>
#       <td id="T_d4940_row1_col9" class="data row1 col9" >0.096946</td>
#       <td id="T_d4940_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_d4940_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_d4940_row1_col12" class="data row1 col12" >31,32,33,34,35</td>
#       <td id="T_d4940_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_d4940_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_d4940_row1_col15" class="data row1 col15" >0.087600</td>
#       <td id="T_d4940_row1_col16" class="data row1 col16" >-0.087600</td>
#       <td id="T_d4940_row1_col17" class="data row1 col17" >0.000000</td>
#       <td id="T_d4940_row1_col18" class="data row1 col18" >0.175200</td>
#       <td id="T_d4940_row1_col19" class="data row1 col19" >0.175200</td>
#       <td id="T_d4940_row1_col20" class="data row1 col20" >0.175200</td>
#     </tr>
#     <tr>
#       <th id="T_d4940_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d4940_row2_col0" class="data row2 col0" >TMD_C_JMD_C-Seg...6,9)-LEVM760105</td>
#       <td id="T_d4940_row2_col1" class="data row2 col1" >Shape</td>
#       <td id="T_d4940_row2_col2" class="data row2 col2" >Side chain length</td>
#       <td id="T_d4940_row2_col3" class="data row2 col3" >Side chain length</td>
#       <td id="T_d4940_row2_col4" class="data row2 col4" >Radius of gyrat... (Levitt, 1976)</td>
#       <td id="T_d4940_row2_col5" class="data row2 col5" >0.233000</td>
#       <td id="T_d4940_row2_col6" class="data row2 col6" >0.137044</td>
#       <td id="T_d4940_row2_col7" class="data row2 col7" >0.137044</td>
#       <td id="T_d4940_row2_col8" class="data row2 col8" >0.161683</td>
#       <td id="T_d4940_row2_col9" class="data row2 col9" >0.176964</td>
#       <td id="T_d4940_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_d4940_row2_col11" class="data row2 col11" >0.000001</td>
#       <td id="T_d4940_row2_col12" class="data row2 col12" >32,33</td>
#       <td id="T_d4940_row2_col13" class="data row2 col13" >1.554800</td>
#       <td id="T_d4940_row2_col14" class="data row2 col14" >2.109848</td>
#       <td id="T_d4940_row2_col15" class="data row2 col15" >0.123890</td>
#       <td id="T_d4940_row2_col16" class="data row2 col16" >-0.360780</td>
#       <td id="T_d4940_row2_col17" class="data row2 col17" >0.236890</td>
#       <td id="T_d4940_row2_col18" class="data row2 col18" >0.282890</td>
#       <td id="T_d4940_row2_col19" class="data row2 col19" >0.362890</td>
#       <td id="T_d4940_row2_col20" class="data row2 col20" >0.338560</td>
#     </tr>
#     <tr>
#       <th id="T_d4940_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d4940_row3_col0" class="data row3 col0" >TMD_C_JMD_C-Seg...3,4)-HUTJ700102</td>
#       <td id="T_d4940_row3_col1" class="data row3 col1" >Energy</td>
#       <td id="T_d4940_row3_col2" class="data row3 col2" >Entropy</td>
#       <td id="T_d4940_row3_col3" class="data row3 col3" >Entropy</td>
#       <td id="T_d4940_row3_col4" class="data row3 col4" >Absolute entrop...Hutchens, 1970)</td>
#       <td id="T_d4940_row3_col5" class="data row3 col5" >0.229000</td>
#       <td id="T_d4940_row3_col6" c

# %% [markdown]
# To change the reference group, use the ``label_ref`` parameter (default=0). Since ``df_feat`` already contains mean difference columns, we must set ``drop=True`` to remove them:

# %%
# Compute difference against average for positive (1) group
df_feat = se.add_sample_mean_dif(X, labels=labels, label_ref=1, df_feat=df_feat, drop=True)
aa.display_df(df_feat, n_cols=-6)
# Out:
# <style type="text/css">
# #T_782cb thead th {
#   background-color: white;
#   color: black;
# }
# #T_782cb tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_782cb tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_782cb th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_782cb  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_782cb" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_782cb_level0_col0" class="col_heading level0 col0" >mean_dif_Protein0</th>
#       <th id="T_782cb_level0_col1" class="col_heading level0 col1" >mean_dif_Protein1</th>
#       <th id="T_782cb_level0_col2" class="col_heading level0 col2" >mean_dif_Protein2</th>
#       <th id="T_782cb_level0_col3" class="col_heading level0 col3" >mean_dif_Protein3</th>
#       <th id="T_782cb_level0_col4" class="col_heading level0 col4" >mean_dif_Protein4</th>
#       <th id="T_782cb_level0_col5" class="col_heading level0 col5" >mean_dif_Protein5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_782cb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_782cb_row0_col0" class="data row0 col0" >-0.100000</td>
#       <td id="T_782cb_row0_col1" class="data row0 col1" >-0.300000</td>
#       <td id="T_782cb_row0_col2" class="data row0 col2" >-0.200000</td>
#       <td id="T_782cb_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_782cb_row0_col4" class="data row0 col4" >-0.000000</td>
#       <td id="T_782cb_row0_col5" class="data row0 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_782cb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_782cb_row1_col0" class="data row1 col0" >-0.087600</td>
#       <td id="T_782cb_row1_col1" class="data row1 col1" >-0.262800</td>
#       <td id="T_782cb_row1_col2" class="data row1 col2" >-0.175200</td>
#       <td id="T_782cb_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_782cb_row1_col4" class="data row1 col4" >-0.000000</td>
#       <td id="T_782cb_row1_col5" class="data row1 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_782cb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_782cb_row2_col0" class="data row2 col0" >-0.204223</td>
#       <td id="T_782cb_row2_col1" class="data row2 col1" >-0.688893</td>
#       <td id="T_782cb_row2_col2" class="data row2 col2" >-0.091223</td>
#       <td id="T_782cb_row2_col3" class="data row2 col3" >-0.045223</td>
#       <td id="T_782cb_row2_col4" class="data row2 col4" >0.034777</td>
#       <td id="T_782cb_row2_col5" class="data row2 col5" >0.010447</td>
#     </tr>
#     <tr>
#       <th id="T_782cb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_782cb_row3_col0" class="data row3 col0" >-0.142667</td>
#       <td id="T_782cb_row3_col1" class="data row3 col1" >-0.543667</td>
#       <td id="T_782cb_row3_col2" class="data row3 col2" >-0.135467</td>
#       <td id="T_782cb_row3_col3" class="data row3 col3" >-0.042467</td>
#       <td id="T_782cb_row3_col4" class="data row3 col4" >0.038533</td>
#       <td id="T_782cb_row3_col5" class="data row3 col5" >0.003933</td>
#     </tr>
#     <tr>
#       <th id="T_782cb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_782cb_row4_col0" class="data row4 col0" >-0.150000</td>
#       <td id="T_782cb_row4_col1" class="data row4 col1" >-0.448000</td>
#       <td id="T_782cb_row4_col2" class="data row4 col2" >-0.054670</td>
#       <td id="T_782cb_row4_col3" class="data row4 col3" >-0.052000</td>
#       <td id="T_782cb_row4_col4" class="data row4 col4" >0.060670</td>
#       <td id="T_782cb_row4_col5" class="data row4 col5" >-0.008670</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Select a specific sample based in its position index in label using the ``sample_positions`` parameter. You can provide its name by the ``names`` parameter:

# %%
# Single sample
df_feat = se.add_sample_mean_dif(X, labels=labels, df_feat=df_feat, drop=True, sample_positions=0, names="Selected_sample")
aa.display_df(df_feat, n_cols=-1)
# Out:
# <style type="text/css">
# #T_bdb36 thead th {
#   background-color: white;
#   color: black;
# }
# #T_bdb36 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_bdb36 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_bdb36 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_bdb36  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_bdb36" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdb36_level0_col0" class="col_heading level0 col0" >mean_dif_Selected_sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdb36_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bdb36_row0_col0" class="data row0 col0" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb36_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bdb36_row1_col0" class="data row1 col0" >0.087600</td>
#     </tr>
#     <tr>
#       <th id="T_bdb36_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bdb36_row2_col0" class="data row2 col0" >0.123890</td>
#     </tr>
#     <tr>
#       <th id="T_bdb36_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_bdb36_row3_col0" class="data row3 col0" >0.131267</td>
#     </tr>
#     <tr>
#       <th id="T_bdb36_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_bdb36_row4_col0" class="data row4 col0" >0.067557</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Three different scenarios are possible:
#
# a) **Single sample**: Compute the difference for a single sample (above).
# b) **Multiple samples**: Compute the difference for multiple samples (all by default).
# c) **Group of samples**: Compute the difference using the average of a group of samples.
#
# To target on specific samples, define their indices in ``sample_positions``. Ensure the ``names`` parameter, if used, corresponds in length to ``sample_positions``.

# %%
# Multiple samples
df_feat = se.add_sample_mean_dif(X, labels=labels, df_feat=df_feat, drop=True, sample_positions=[0, 1], names=["Sample 1", "Sample 2"])
aa.display_df(df_feat, n_cols=-2)
# Out:
# <style type="text/css">
# #T_7a472 thead th {
#   background-color: white;
#   color: black;
# }
# #T_7a472 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_7a472 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_7a472 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_7a472  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_7a472" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a472_level0_col0" class="col_heading level0 col0" >mean_dif_Sample 1</th>
#       <th id="T_7a472_level0_col1" class="col_heading level0 col1" >mean_dif_Sample 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a472_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7a472_row0_col0" class="data row0 col0" >0.100000</td>
#       <td id="T_7a472_row0_col1" class="data row0 col1" >-0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_7a472_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7a472_row1_col0" class="data row1 col0" >0.087600</td>
#       <td id="T_7a472_row1_col1" class="data row1 col1" >-0.087600</td>
#     </tr>
#     <tr>
#       <th id="T_7a472_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7a472_row2_col0" class="data row2 col0" >0.123890</td>
#       <td id="T_7a472_row2_col1" class="data row2 col1" >-0.360780</td>
#     </tr>
#     <tr>
#       <th id="T_7a472_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7a472_row3_col0" class="data row3 col0" >0.131267</td>
#       <td id="T_7a472_row3_col1" class="data row3 col1" >-0.269733</td>
#     </tr>
#     <tr>
#       <th id="T_7a472_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7a472_row4_col0" class="data row4 col0" >0.067557</td>
#       <td id="T_7a472_row4_col1" class="data row4 col1" >-0.230443</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To compute the group average, set ``group_average=True`` and specify the sample indices in `sample_positions`.Assign a name to the group using the ``names`` parameter; if not provided, 'Group' will be used as the default name:

# %%
# Group of samples
df_feat = se.add_sample_mean_dif(X, labels=labels, df_feat=df_feat, drop=True, sample_positions=[0, 1], group_average=True)
aa.display_df(df_feat, n_cols=-1)
# Out:
# <style type="text/css">
# #T_42bef thead th {
#   background-color: white;
#   color: black;
# }
# #T_42bef tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_42bef tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_42bef th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_42bef  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_42bef" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42bef_level0_col0" class="col_heading level0 col0" >mean_dif_Group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42bef_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_42bef_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42bef_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_42bef_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42bef_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_42bef_row2_col0" class="data row2 col0" >-0.118445</td>
#     </tr>
#     <tr>
#       <th id="T_42bef_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_42bef_row3_col0" class="data row3 col0" >-0.069233</td>
#     </tr>
#     <tr>
#       <th id="T_42bef_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_42bef_row4_col0" class="data row4 col0" >-0.081443</td>
#     </tr>
#   </tbody>
# </table>
