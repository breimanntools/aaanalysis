# %% [markdown]
# To demonstrate the ``ShapExplainer().add_feat_impact()`` method, we obtain the DOM_GSEC example dataset and its respective feature set (see [Breimann24c]_):

# %%
import aaanalysis as aa
aa.options["verbose"] = False # Disable verbosity

df_seq = aa.load_dataset(name="DOM_GSEC", n=3)
labels = df_seq["label"].to_list()
df_feat = aa.load_features(name="DOM_GSEC").head(5)

# Create feature matrix
sf = aa.SequenceFeature()
df_parts = sf.get_df_parts(df_seq=df_seq)
X = sf.feature_matrix(features=df_feat["feature"], df_parts=df_parts)

aa.display_df(df_seq)
# Out:
# <style type="text/css">
# #T_5b7d2 thead th {
#   background-color: white;
#   color: black;
# }
# #T_5b7d2 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_5b7d2 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_5b7d2 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_5b7d2  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_5b7d2" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b7d2_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_5b7d2_level0_col1" class="col_heading level0 col1" >sequence</th>
#       <th id="T_5b7d2_level0_col2" class="col_heading level0 col2" >label</th>
#       <th id="T_5b7d2_level0_col3" class="col_heading level0 col3" >tmd_start</th>
#       <th id="T_5b7d2_level0_col4" class="col_heading level0 col4" >tmd_stop</th>
#       <th id="T_5b7d2_level0_col5" class="col_heading level0 col5" >jmd_n</th>
#       <th id="T_5b7d2_level0_col6" class="col_heading level0 col6" >tmd</th>
#       <th id="T_5b7d2_level0_col7" class="col_heading level0 col7" >jmd_c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b7d2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5b7d2_row0_col0" class="data row0 col0" >Q14802</td>
#       <td id="T_5b7d2_row0_col1" class="data row0 col1" >MQKVTLGLLVFLAGF...PGETPPLITPGSAQS</td>
#       <td id="T_5b7d2_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_5b7d2_row0_col3" class="data row0 col3" >37</td>
#       <td id="T_5b7d2_row0_col4" class="data row0 col4" >59</td>
#       <td id="T_5b7d2_row0_col5" class="data row0 col5" >NSPFYYDWHS</td>
#       <td id="T_5b7d2_row0_col6" class="data row0 col6" >LQVGGLICAGVLCAMGIIIVMSA</td>
#       <td id="T_5b7d2_row0_col7" class="data row0 col7" >KCKCKFGQKS</td>
#     </tr>
#     <tr>
#       <th id="T_5b7d2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5b7d2_row1_col0" class="data row1 col0" >Q86UE4</td>
#       <td id="T_5b7d2_row1_col1" class="data row1 col1" >MAARSWQDELAQQAE...SPKQIKKKKKARRET</td>
#       <td id="T_5b7d2_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_5b7d2_row1_col3" class="data row1 col3" >50</td>
#       <td id="T_5b7d2_row1_col4" class="data row1 col4" >72</td>
#       <td id="T_5b7d2_row1_col5" class="data row1 col5" >LGLEPKRYPG</td>
#       <td id="T_5b7d2_row1_col6" class="data row1 col6" >WVILVGTGALGLLLLFLLGYGWA</td>
#       <td id="T_5b7d2_row1_col7" class="data row1 col7" >AACAGARKKR</td>
#     </tr>
#     <tr>
#       <th id="T_5b7d2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5b7d2_row2_col0" class="data row2 col0" >Q969W9</td>
#       <td id="T_5b7d2_row2_col1" class="data row2 col1" >MHRLMGVNSTAAAAA...AIWSKEKDKQKGHPL</td>
#       <td id="T_5b7d2_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_5b7d2_row2_col3" class="data row2 col3" >41</td>
#       <td id="T_5b7d2_row2_col4" class="data row2 col4" >63</td>
#       <td id="T_5b7d2_row2_col5" class="data row2 col5" >FQSMEITELE</td>
#       <td id="T_5b7d2_row2_col6" class="data row2 col6" >FVQIIIIVVVMMVMVVVITCLLS</td>
#       <td id="T_5b7d2_row2_col7" class="data row2 col7" >HYKLSARSFI</td>
#     </tr>
#     <tr>
#       <th id="T_5b7d2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5b7d2_row3_col0" class="data row3 col0" >P05067</td>
#       <td id="T_5b7d2_row3_col1" class="data row3 col1" >MLPGLALLLLAAWTA...GYENPTYKFFEQMQN</td>
#       <td id="T_5b7d2_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_5b7d2_row3_col3" class="data row3 col3" >701</td>
#       <td id="T_5b7d2_row3_col4" class="data row3 col4" >723</td>
#       <td id="T_5b7d2_row3_col5" class="data row3 col5" >FAEDVGSNKG</td>
#       <td id="T_5b7d2_row3_col6" class="data row3 col6" >AIIGLMVGGVVIATVIVITLVML</td>
#       <td id="T_5b7d2_row3_col7" class="data row3 col7" >KKKQYTSIHH</td>
#     </tr>
#     <tr>
#       <th id="T_5b7d2_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_5b7d2_row4_col0" class="data row4 col0" >P14925</td>
#       <td id="T_5b7d2_row4_col1" class="data row4 col1" >MAGRARSGLLLLLLG...EEEYSAPLPKPAPSS</td>
#       <td id="T_5b7d2_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_5b7d2_row4_col3" class="data row4 col3" >868</td>
#       <td id="T_5b7d2_row4_col4" class="data row4 col4" >890</td>
#       <td id="T_5b7d2_row4_col5" class="data row4 col5" >KLSTEPGSGV</td>
#       <td id="T_5b7d2_row4_col6" class="data row4 col6" >SVVLITTLLVIPVLVLLAIVMFI</td>
#       <td id="T_5b7d2_row4_col7" class="data row4 col7" >RWKKSRAFGD</td>
#     </tr>
#     <tr>
#       <th id="T_5b7d2_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_5b7d2_row5_col0" class="data row5 col0" >P70180</td>
#       <td id="T_5b7d2_row5_col1" class="data row5 col1" >MRSLLLFTFSACVLL...RELREDSIRSHFSVA</td>
#       <td id="T_5b7d2_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_5b7d2_row5_col3" class="data row5 col3" >477</td>
#       <td id="T_5b7d2_row5_col4" class="data row5 col4" >499</td>
#       <td id="T_5b7d2_row5_col5" class="data row5 col5" >PCKSSGGLEE</td>
#       <td id="T_5b7d2_row5_col6" class="data row5 col6" >SAVTGIVVGALLGAGLLMAFYFF</td>
#       <td id="T_5b7d2_row5_col7" class="data row5 col7" >RKKYRITIER</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can now create a ``ShapExplainer`` object and fit it to create the ``shap_values``, which are saved internally:

# %%
se = aa.ShapExplainer()
se.fit(X, labels=labels)

shap_values = se.shap_values

# Print SHAP values and expected value
print("SHAP values explain the feature impact for 3 negative and 3 positive samples")
print(shap_values.round(2))
# Out:
# SHAP values explain the feature impact for 3 negative and 3 positive samples
# [[-0.11 -0.11 -0.08 -0.09 -0.07]
#  [-0.12 -0.12 -0.08 -0.09 -0.08]
#  [-0.14 -0.14 -0.04 -0.09 -0.03]
#  [ 0.14  0.13  0.04  0.09  0.04]
#  [ 0.13  0.12  0.08  0.09  0.08]
#  [ 0.13  0.12  0.08  0.09  0.07]]

# %% [markdown]
# We can now include the feature impact (i.e., SHAP values normalized such that their absolute values sum up to 100%) by providing ``df_feat`` to the ``ShapExplainer().add_feat_impact()`` method:

# %%
# Add feature impact of each sample (Protein0 to Protein5)
df_feat = se.add_feat_impact(df_feat=df_feat)
aa.display_df(df_feat)
# Out:
# <style type="text/css">
# #T_a90b8 thead th {
#   background-color: white;
#   color: black;
# }
# #T_a90b8 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_a90b8 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_a90b8 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_a90b8  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_a90b8" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a90b8_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_a90b8_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_a90b8_level0_col2" class="col_heading level0 col2" >subcategory</th>
#       <th id="T_a90b8_level0_col3" class="col_heading level0 col3" >scale_name</th>
#       <th id="T_a90b8_level0_col4" class="col_heading level0 col4" >scale_description</th>
#       <th id="T_a90b8_level0_col5" class="col_heading level0 col5" >abs_auc</th>
#       <th id="T_a90b8_level0_col6" class="col_heading level0 col6" >abs_mean_dif</th>
#       <th id="T_a90b8_level0_col7" class="col_heading level0 col7" >mean_dif</th>
#       <th id="T_a90b8_level0_col8" class="col_heading level0 col8" >std_test</th>
#       <th id="T_a90b8_level0_col9" class="col_heading level0 col9" >std_ref</th>
#       <th id="T_a90b8_level0_col10" class="col_heading level0 col10" >p_val_mann_whitney</th>
#       <th id="T_a90b8_level0_col11" class="col_heading level0 col11" >p_val_fdr_bh</th>
#       <th id="T_a90b8_level0_col12" class="col_heading level0 col12" >positions</th>
#       <th id="T_a90b8_level0_col13" class="col_heading level0 col13" >feat_importance</th>
#       <th id="T_a90b8_level0_col14" class="col_heading level0 col14" >feat_importance_std</th>
#       <th id="T_a90b8_level0_col15" class="col_heading level0 col15" >feat_impact_Protein0</th>
#       <th id="T_a90b8_level0_col16" class="col_heading level0 col16" >feat_impact_Protein1</th>
#       <th id="T_a90b8_level0_col17" class="col_heading level0 col17" >feat_impact_Protein2</th>
#       <th id="T_a90b8_level0_col18" class="col_heading level0 col18" >feat_impact_Protein3</th>
#       <th id="T_a90b8_level0_col19" class="col_heading level0 col19" >feat_impact_Protein4</th>
#       <th id="T_a90b8_level0_col20" class="col_heading level0 col20" >feat_impact_Protein5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a90b8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a90b8_row0_col0" class="data row0 col0" >TMD_C_JMD_C-Seg...3,4)-KLEP840101</td>
#       <td id="T_a90b8_row0_col1" class="data row0 col1" >Energy</td>
#       <td id="T_a90b8_row0_col2" class="data row0 col2" >Charge</td>
#       <td id="T_a90b8_row0_col3" class="data row0 col3" >Charge</td>
#       <td id="T_a90b8_row0_col4" class="data row0 col4" >Net charge (Kle...n et al., 1984)</td>
#       <td id="T_a90b8_row0_col5" class="data row0 col5" >0.244000</td>
#       <td id="T_a90b8_row0_col6" class="data row0 col6" >0.103666</td>
#       <td id="T_a90b8_row0_col7" class="data row0 col7" >0.103666</td>
#       <td id="T_a90b8_row0_col8" class="data row0 col8" >0.106692</td>
#       <td id="T_a90b8_row0_col9" class="data row0 col9" >0.110506</td>
#       <td id="T_a90b8_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_a90b8_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_a90b8_row0_col12" class="data row0 col12" >31,32,33,34,35</td>
#       <td id="T_a90b8_row0_col13" class="data row0 col13" >0.970400</td>
#       <td id="T_a90b8_row0_col14" class="data row0 col14" >1.438918</td>
#       <td id="T_a90b8_row0_col15" class="data row0 col15" >-23.000000</td>
#       <td id="T_a90b8_row0_col16" class="data row0 col16" >-24.920000</td>
#       <td id="T_a90b8_row0_col17" class="data row0 col17" >-31.600000</td>
#       <td id="T_a90b8_row0_col18" class="data row0 col18" >30.690000</td>
#       <td id="T_a90b8_row0_col19" class="data row0 col19" >25.370000</td>
#       <td id="T_a90b8_row0_col20" class="data row0 col20" >26.380000</td>
#     </tr>
#     <tr>
#       <th id="T_a90b8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a90b8_row1_col0" class="data row1 col0" >TMD_C_JMD_C-Seg...3,4)-FINA910104</td>
#       <td id="T_a90b8_row1_col1" class="data row1 col1" >Conformation</td>
#       <td id="T_a90b8_row1_col2" class="data row1 col2" >α-helix (C-cap)</td>
#       <td id="T_a90b8_row1_col3" class="data row1 col3" >α-helix termination</td>
#       <td id="T_a90b8_row1_col4" class="data row1 col4" >Helix terminati...n et al., 1991)</td>
#       <td id="T_a90b8_row1_col5" class="data row1 col5" >0.243000</td>
#       <td id="T_a90b8_row1_col6" class="data row1 col6" >0.085064</td>
#       <td id="T_a90b8_row1_col7" class="data row1 col7" >0.085064</td>
#       <td id="T_a90b8_row1_col8" class="data row1 col8" >0.098774</td>
#       <td id="T_a90b8_row1_col9" class="data row1 col9" >0.096946</td>
#       <td id="T_a90b8_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_a90b8_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_a90b8_row1_col12" class="data row1 col12" >31,32,33,34,35</td>
#       <td id="T_a90b8_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_a90b8_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_a90b8_row1_col15" class="data row1 col15" >-22.840000</td>
#       <td id="T_a90b8_row1_col16" class="data row1 col16" >-23.780000</td>
#       <td id="T_a90b8_row1_col17" class="data row1 col17" >-31.530000</td>
#       <td id="T_a90b8_row1_col18" class="data row1 col18" >29.850000</td>
#       <td id="T_a90b8_row1_col19" class="data row1 col19" >25.060000</td>
#       <td id="T_a90b8_row1_col20" class="data row1 col20" >25.550000</td>
#     </tr>
#     <tr>
#       <th id="T_a90b8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a90b8_row2_col0" class="data row2 col0" >TMD_C_JMD_C-Seg...6,9)-LEVM760105</td>
#       <td id="T_a90b8_row2_col1" class="data row2 col1" >Shape</td>
#       <td id="T_a90b8_row2_col2" class="data row2 col2" >Side chain length</td>
#       <td id="T_a90b8_row2_col3" class="data row2 col3" >Side chain length</td>
#       <td id="T_a90b8_row2_col4" class="data row2 col4" >Radius of gyrat... (Levitt, 1976)</td>
#       <td id="T_a90b8_row2_col5" class="data row2 col5" >0.233000</td>
#       <td id="T_a90b8_row2_col6" class="data row2 col6" >0.137044</td>
#       <td id="T_a90b8_row2_col7" class="data row2 col7" >0.137044</td>
#       <td id="T_a90b8_row2_col8" class="data row2 col8" >0.161683</td>
#       <td id="T_a90b8_row2_col9" class="data row2 col9" >0.176964</td>
#       <td id="T_a90b8_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_a90b8_row2_col11" class="data row2 col11" >0.000001</td>
#       <td id="T_a90b8_row2_col12" class="data row2 col12" >32,33</td>
#       <td id="T_a90b8_row2_col13" class="data row2 col13" >1.554800</td>
#       <td id="T_a90b8_row2_col14" class="data row2 col14" >2.109848</td>
#       <td id="T_a90b8_row2_col15" class="data row2 col15" >-18.410000</td>
#       <td id="T_a90b8_row2_col16" class="data row2 col16" >-16.990000</td>
#       <td id="T_a90b8_row2_col17" class="data row2 col17" >-9.600000</td>
#       <td id="T_a90b8_row2_col18" class="data row2 col18" >10.000000</td>
#       <td id="T_a90b8_row2_col19" class="data row2 col19" >16.080000</td>
#       <td id="T_a90b8_row2_col20" class="data row2 col20" >16.120000</td>
#     </tr>
#     <tr>
#       <th id="T_a90b8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a90b8_row3_col0" class="data row3 col0" >TMD_C_JMD_C-Seg...3,4)-HUTJ700102</td>
#       <td id="T_a90b8_row3_col1" class="data row3 col1" >Energy</td>
#       <td id="T_a90b8_row3_col2" class="data row3 col2" >Entropy</td>
#       <td id="T_a90b8_row3_col3" class="data row3 col3" >Entropy</td>
#       <td id="T_a90b8_row3_col4" class="data row3 col4" >Absolute entrop...Hutchens, 1970)</td>
#       <td id="T_a90b8_row3_col5" class="data row3 col5" >0.22900

# %% [markdown]
# To include the impact of a specific sample, use the ``sample_positions`` parameter indicating the position index of the sample within the ``shap_values`` attribute (the same as in the ``labels`` provided to the ``ShapExplainer().fit()`` method). You need to set ``drop=True`` to override the feature impact columns:

# %%
# First protein
df_feat = se.add_feat_impact(df_feat=df_feat, drop=True, sample_positions=0)
aa.display_df(df_feat, n_cols=-1)
# Out:
# <style type="text/css">
# #T_e62c3 thead th {
#   background-color: white;
#   color: black;
# }
# #T_e62c3 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_e62c3 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_e62c3 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_e62c3  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_e62c3" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e62c3_level0_col0" class="col_heading level0 col0" >feat_impact_Protein0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e62c3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e62c3_row0_col0" class="data row0 col0" >-23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e62c3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e62c3_row1_col0" class="data row1 col0" >-22.840000</td>
#     </tr>
#     <tr>
#       <th id="T_e62c3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e62c3_row2_col0" class="data row2 col0" >-18.410000</td>
#     </tr>
#     <tr>
#       <th id="T_e62c3_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e62c3_row3_col0" class="data row3 col0" >-20.060000</td>
#     </tr>
#     <tr>
#       <th id="T_e62c3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e62c3_row4_col0" class="data row4 col0" >-15.690000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can provide a specific ``names`` for the corresponding sample:

# %%
# Single sample
df_feat = se.add_feat_impact(df_feat=df_feat, drop=True, sample_positions=0, names="Selected_sample")
aa.display_df(df_feat, n_cols=-1)
# Out:
# <style type="text/css">
# #T_2dff4 thead th {
#   background-color: white;
#   color: black;
# }
# #T_2dff4 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_2dff4 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_2dff4 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_2dff4  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_2dff4" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dff4_level0_col0" class="col_heading level0 col0" >feat_impact_Selected_sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dff4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2dff4_row0_col0" class="data row0 col0" >-23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2dff4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2dff4_row1_col0" class="data row1 col0" >-22.840000</td>
#     </tr>
#     <tr>
#       <th id="T_2dff4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2dff4_row2_col0" class="data row2 col0" >-18.410000</td>
#     </tr>
#     <tr>
#       <th id="T_2dff4_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2dff4_row3_col0" class="data row3 col0" >-20.060000</td>
#     </tr>
#     <tr>
#       <th id="T_2dff4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2dff4_row4_col0" class="data row4 col0" >-15.690000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Computing feature impact**
#
# Three different scenarios are possible:
#
# a) **Single sample**: Compute the feature impact for a single sample (above).
# b) **Multiple samples**: Compute the feature impact for multiple samples (all by default).
# c) **Group of samples**: Compute the average feature impact and standard deviation for a group.
#
# To focus on specific samples, specify their indices in ``sample_positions``. If ``names`` is provided, its length should match ``sample_positions``.

# %%
# Multiple samples
df_feat = se.add_feat_impact(df_feat=df_feat, drop=True, sample_positions=[0, 1], names=["Sample 1", "Sample 2"])
aa.display_df(df_feat, n_cols=-2)
# Out:
# <style type="text/css">
# #T_86a4a thead th {
#   background-color: white;
#   color: black;
# }
# #T_86a4a tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_86a4a tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_86a4a th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_86a4a  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_86a4a" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86a4a_level0_col0" class="col_heading level0 col0" >feat_impact_Sample 1</th>
#       <th id="T_86a4a_level0_col1" class="col_heading level0 col1" >feat_impact_Sample 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86a4a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_86a4a_row0_col0" class="data row0 col0" >-23.000000</td>
#       <td id="T_86a4a_row0_col1" class="data row0 col1" >-24.920000</td>
#     </tr>
#     <tr>
#       <th id="T_86a4a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_86a4a_row1_col0" class="data row1 col0" >-22.840000</td>
#       <td id="T_86a4a_row1_col1" class="data row1 col1" >-23.780000</td>
#     </tr>
#     <tr>
#       <th id="T_86a4a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_86a4a_row2_col0" class="data row2 col0" >-18.410000</td>
#       <td id="T_86a4a_row2_col1" class="data row2 col1" >-16.990000</td>
#     </tr>
#     <tr>
#       <th id="T_86a4a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_86a4a_row3_col0" class="data row3 col0" >-20.060000</td>
#       <td id="T_86a4a_row3_col1" class="data row3 col1" >-18.600000</td>
#     </tr>
#     <tr>
#       <th id="T_86a4a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_86a4a_row4_col0" class="data row4 col0" >-15.690000</td>
#       <td id="T_86a4a_row4_col1" class="data row4 col1" >-15.700000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To calculate the group average, set ``group_average=True`` and specify the sample indices in `sample_positions`. Provide a ``names`` for the group, or 'Group' will be used by default:

# %%
# Group of samples
df_feat = se.add_feat_impact(df_feat=df_feat, drop=True, sample_positions=[0, 1], group_average=True)
aa.display_df(df_feat, n_cols=-2)
# Out:
# <style type="text/css">
# #T_1ee17 thead th {
#   background-color: white;
#   color: black;
# }
# #T_1ee17 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_1ee17 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_1ee17 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_1ee17  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_1ee17" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ee17_level0_col0" class="col_heading level0 col0" >feat_impact_Group</th>
#       <th id="T_1ee17_level0_col1" class="col_heading level0 col1" >feat_impact_std_Group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ee17_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1ee17_row0_col0" class="data row0 col0" >-24.000000</td>
#       <td id="T_1ee17_row0_col1" class="data row0 col1" >1.837384</td>
#     </tr>
#     <tr>
#       <th id="T_1ee17_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1ee17_row1_col0" class="data row1 col0" >-23.330000</td>
#       <td id="T_1ee17_row1_col1" class="data row1 col1" >1.323308</td>
#     </tr>
#     <tr>
#       <th id="T_1ee17_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1ee17_row2_col0" class="data row2 col0" >-17.670000</td>
#       <td id="T_1ee17_row2_col1" class="data row2 col1" >0.058110</td>
#     </tr>
#     <tr>
#       <th id="T_1ee17_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1ee17_row3_col0" class="data row3 col0" >-19.310000</td>
#       <td id="T_1ee17_row3_col1" class="data row3 col1" >0.021083</td>
#     </tr>
#     <tr>
#       <th id="T_1ee17_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_1ee17_row4_col0" class="data row4 col0" >-15.700000</td>
#       <td id="T_1ee17_row4_col1" class="data row4 col1" >0.582510</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Setting ``shap_feat_importance=True``, will compute the SHAP value-based feature importance:

# %%
# SHAP value-based feature importance
df_feat = se.add_feat_impact(df_feat=df_feat, drop=True, shap_feat_importance=True)
aa.display_df(df_feat, n_cols=-1)
# Out:
# <style type="text/css">
# #T_8e147 thead th {
#   background-color: white;
#   color: black;
# }
# #T_8e147 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_8e147 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_8e147 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_8e147  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_8e147" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e147_level0_col0" class="col_heading level0 col0" >feat_importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e147_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8e147_row0_col0" class="data row0 col0" >26.870000</td>
#     </tr>
#     <tr>
#       <th id="T_8e147_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8e147_row1_col0" class="data row1 col0" >26.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8e147_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8e147_row2_col0" class="data row2 col0" >14.680000</td>
#     </tr>
#     <tr>
#       <th id="T_8e147_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8e147_row3_col0" class="data row3 col0" >19.280000</td>
#     </tr>
#     <tr>
#       <th id="T_8e147_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8e147_row4_col0" class="data row4 col0" >12.880000</td>
#     </tr>
#   </tbody>
# </table>
