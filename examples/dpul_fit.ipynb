# %% [raw]
# Create a small example dataset for dPUlearn containing positive (1) and unlabeled (2) data samples:

# %%
import aaanalysis as aa
import pandas as pd
import numpy as np
aa.options["verbose"] = False
X = np.array([[0.2, 0.1], [0.25, 0.2], [0.2, 0.3], [0.5, 0.7]])
labels = np.array([1, 2, 2, 2])

# %% [markdown]
# Use ``dPULearn`` with default Principal Component Analysis (PCA) to obtain a defined number of reliable negatives samples (0) by specifying the ``n_unl_to_neg`` parameter:

# %%
dpul = aa.dPULearn()
dpul.fit(X=X, labels=labels, n_unl_to_neg=1)
df_pu = dpul.df_pu_
labels = dpul.labels_ # Updated labels
aa.display_df(df_pu)
# Out:
# <style type="text/css">
# #T_5a350 thead th {
#   background-color: white;
#   color: black;
# }
# #T_5a350 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_5a350 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_5a350 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_5a350  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_5a350 table {
#   font-size: 12px;
# }
# </style>
# <table id="T_5a350" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a350_level0_col0" class="col_heading level0 col0" >selection_via</th>
#       <th id="T_5a350_level0_col1" class="col_heading level0 col1" >PC1 (100.0%)</th>
#       <th id="T_5a350_level0_col2" class="col_heading level0 col2" >PC1 (100.0%)_abs_dif</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a350_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5a350_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_5a350_row0_col1" class="data row0 col1" >-0.400000</td>
#       <td id="T_5a350_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5a350_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5a350_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_5a350_row1_col1" class="data row1 col1" >-0.200000</td>
#       <td id="T_5a350_row1_col2" class="data row1 col2" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_5a350_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5a350_row2_col0" class="data row2 col0" >None</td>
#       <td id="T_5a350_row2_col1" class="data row2 col1" >0.400000</td>
#       <td id="T_5a350_row2_col2" class="data row2 col2" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_5a350_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5a350_row3_col0" class="data row3 col0" >PC1</td>
#       <td id="T_5a350_row3_col1" class="data row3 col1" >0.800000</td>
#       <td id="T_5a350_row3_col2" class="data row3 col2" >1.200000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As a real-world example, you can load our γ-secretase substrate prediction dataset containing substrates (positive samples, 1) and a redundancy-reduced set of single-span type I transmembrane proteins with unknown substrates status (unlabeled samples, 2):

# %%
df_seq = aa.load_dataset(name="DOM_GSEC_PU")
labels = df_seq["label"].to_numpy()
n_pos = sum([x == 1 for x in labels])   # Get number of positive samples
aa.display_df(df=df_seq, show_shape=True)
# Out:
# DataFrame shape: (694, 8)
# <style type="text/css">
# #T_9b798 thead th {
#   background-color: white;
#   color: black;
# }
# #T_9b798 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_9b798 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_9b798 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_9b798  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_9b798 table {
#   font-size: 12px;
# }
# </style>
# <table id="T_9b798" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b798_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_9b798_level0_col1" class="col_heading level0 col1" >sequence</th>
#       <th id="T_9b798_level0_col2" class="col_heading level0 col2" >label</th>
#       <th id="T_9b798_level0_col3" class="col_heading level0 col3" >tmd_start</th>
#       <th id="T_9b798_level0_col4" class="col_heading level0 col4" >tmd_stop</th>
#       <th id="T_9b798_level0_col5" class="col_heading level0 col5" >jmd_n</th>
#       <th id="T_9b798_level0_col6" class="col_heading level0 col6" >tmd</th>
#       <th id="T_9b798_level0_col7" class="col_heading level0 col7" >jmd_c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b798_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9b798_row0_col0" class="data row0 col0" >P05067</td>
#       <td id="T_9b798_row0_col1" class="data row0 col1" >MLPGLALLLLAA...NPTYKFFEQMQN</td>
#       <td id="T_9b798_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_9b798_row0_col3" class="data row0 col3" >701</td>
#       <td id="T_9b798_row0_col4" class="data row0 col4" >723</td>
#       <td id="T_9b798_row0_col5" class="data row0 col5" >FAEDVGSNKG</td>
#       <td id="T_9b798_row0_col6" class="data row0 col6" >AIIGLMVGGVVIATVIVITLVML</td>
#       <td id="T_9b798_row0_col7" class="data row0 col7" >KKKQYTSIHH</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9b798_row1_col0" class="data row1 col0" >P14925</td>
#       <td id="T_9b798_row1_col1" class="data row1 col1" >MAGRARSGLLLL...YSAPLPKPAPSS</td>
#       <td id="T_9b798_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_9b798_row1_col3" class="data row1 col3" >868</td>
#       <td id="T_9b798_row1_col4" class="data row1 col4" >890</td>
#       <td id="T_9b798_row1_col5" class="data row1 col5" >KLSTEPGSGV</td>
#       <td id="T_9b798_row1_col6" class="data row1 col6" >SVVLITTLLVIPVLVLLAIVMFI</td>
#       <td id="T_9b798_row1_col7" class="data row1 col7" >RWKKSRAFGD</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9b798_row2_col0" class="data row2 col0" >P70180</td>
#       <td id="T_9b798_row2_col1" class="data row2 col1" >MRSLLLFTFSAC...REDSIRSHFSVA</td>
#       <td id="T_9b798_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_9b798_row2_col3" class="data row2 col3" >477</td>
#       <td id="T_9b798_row2_col4" class="data row2 col4" >499</td>
#       <td id="T_9b798_row2_col5" class="data row2 col5" >PCKSSGGLEE</td>
#       <td id="T_9b798_row2_col6" class="data row2 col6" >SAVTGIVVGALLGAGLLMAFYFF</td>
#       <td id="T_9b798_row2_col7" class="data row2 col7" >RKKYRITIER</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9b798_row3_col0" class="data row3 col0" >Q03157</td>
#       <td id="T_9b798_row3_col1" class="data row3 col1" >MGPTSPAARGQG...ENPTYRFLEERP</td>
#       <td id="T_9b798_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_9b798_row3_col3" class="data row3 col3" >585</td>
#       <td id="T_9b798_row3_col4" class="data row3 col4" >607</td>
#       <td id="T_9b798_row3_col5" class="data row3 col5" >APSGTGVSRE</td>
#       <td id="T_9b798_row3_col6" class="data row3 col6" >ALSGLLIMGAGGGSLIVLSLLLL</td>
#       <td id="T_9b798_row3_col7" class="data row3 col7" >RKKKPYGTIS</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9b798_row4_col0" class="data row4 col0" >Q06481</td>
#       <td id="T_9b798_row4_col1" class="data row4 col1" >MAATGTAAAAAT...NPTYKYLEQMQI</td>
#       <td id="T_9b798_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_9b798_row4_col3" class="data row4 col3" >694</td>
#       <td id="T_9b798_row4_col4" class="data row4 col4" >716</td>
#       <td id="T_9b798_row4_col5" class="data row4 col5" >LREDFSLSSS</td>
#       <td id="T_9b798_row4_col6" class="data row4 col6" >ALIGLLVIAVAIATVIVISLVML</td>
#       <td id="T_9b798_row4_col7" class="data row4 col7" >RKRQYGTISH</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9b798_row5_col0" class="data row5 col0" >P35613</td>
#       <td id="T_9b798_row5_col1" class="data row5 col1" >MAAALFVLLGFA...DKGKNVRQRNSS</td>
#       <td id="T_9b798_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_9b798_row5_col3" class="data row5 col3" >323</td>
#       <td id="T_9b798_row5_col4" class="data row5 col4" >345</td>
#       <td id="T_9b798_row5_col5" class="data row5 col5" >IITLRVRSHL</td>
#       <td id="T_9b798_row5_col6" class="data row5 col6" >AALWPFLGIVAEVLVLVTIIFIY</td>
#       <td id="T_9b798_row5_col7" class="data row5 col7" >EKRRKPEDVL</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_9b798_row6_col0" class="data row6 col0" >P35070</td>
#       <td id="T_9b798_row6_col1" class="data row6 col1" >MDRAARCSGASS...PINEDIEETNIA</td>
#       <td id="T_9b798_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_9b798_row6_col3" class="data row6 col3" >119</td>
#       <td id="T_9b798_row6_col4" class="data row6 col4" >141</td>
#       <td id="T_9b798_row6_col5" class="data row6 col5" >LFYLRGDRGQ</td>
#       <td id="T_9b798_row6_col6" class="data row6 col6" >ILVICLIAVMVVFIILVIGVCTC</td>
#       <td id="T_9b798_row6_col7" class="data row6 col7" >CHPLRKRRKR</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_9b798_row7_col0" class="data row7 col0" >P09803</td>
#       <td id="T_9b798_row7_col1" class="data row7 col1" >MGARCRSFSALL...KLADMYGGGEDD</td>
#       <td id="T_9b798_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_9b798_row7_col3" class="data row7 col3" >711</td>
#       <td id="T_9b798_row7_col4" class="data row7 col4" >733</td>
#       <td id="T_9b798_row7_col5" class="data row7 col5" >GIVAAGLQVP</td>
#       <td id="T_9b798_row7_col6" class="data row7 col6" >AILGILGGILALLILILLLLLFL</td>
#       <td id="T_9b798_row7_col7" class="data row7 col7" >RRRTVVKEPL</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_9b798_row8_col0" class="data row8 col0" >P19022</td>
#       <td id="T_9b798_row8_col1" class="data row8 col1" >MCRIAGALRTLL...KKLADMYGGGDD</td>
#       <td id="T_9b798_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_9b798_row8_col3" class="data row8 col3" >724</td>
#       <td id="T_9b798_row8_col4" class="data row8 col4" >746</td>
#       <td id="T_9b798_row8_col5" class="data row8 col5" >RIVGAGLGTG</td>
#       <td id="T_9b798_row8_col6" class="data row8 col6" >AIIAILLCIIILLILVLMFVVWM</td>
#       <td id="T_9b798_row8_col7" class="data row8 col7" >KRRDKERQAK</td>
#     </tr>
#     <tr>
#       <th id="T_9b798_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_9b798_row9_col0" class="data row9 col0" >P16070</td>
#       <td id="T_9b798_row9_col1" class="data row9 col1" >MDKFWWHAAWGL...RNLQNVDMKIGV</td>
#       <td id="T_9b798_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_9b798_row9_col3" class="data row9 col3" >650</td>
#       <td id="T_9b798_row9_col4" class="data row9 col4" >672</td>
#       <td id="T_9b798_row9_col5" class="data row9 col5" >GPIRTPQIPE</td>
#       <td id="T_9b798_row9_col6" class="data row9 col6" >WLIILASLLALALILAVCIAVNS</td>
#       <td id="T_9b798_row9_col7" class="data

# %% [raw]
# Using the respective features, we can create a feature matrix and obtiain 'reliable' non-substrates by dPULearn:

# %%
df_feat = aa.load_features(name="DOM_GSEC")
sf = aa.SequenceFeature()
df_parts = sf.get_df_parts(df_seq=df_seq)
X = sf.feature_matrix(features=df_feat["feature"], df_parts=df_parts)
# Number of positive (1) and unlabeled (2) samples
print(pd.Series(labels).value_counts())
dpul.fit(X=X, labels=labels, n_unl_to_neg=n_pos)
df_pu = dpul.df_pu_
new_labels = dpul.labels_ 
# Number of updated labels containing reliable negatives (0)
print(pd.Series(new_labels).value_counts())
aa.display_df(df=df_pu, show_shape=True)
# Out:
# 2    631
# 1     63
# Name: count, dtype: int64
# 2    568
# 1     63
# 0     63
# Name: count, dtype: int64
# DataFrame shape: (694, 15)
# <style type="text/css">
# #T_061a0 thead th {
#   background-color: white;
#   color: black;
# }
# #T_061a0 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_061a0 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_061a0 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_061a0  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_061a0 table {
#   font-size: 12px;
# }
# </style>
# <table id="T_061a0" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_061a0_level0_col0" class="col_heading level0 col0" >selection_via</th>
#       <th id="T_061a0_level0_col1" class="col_heading level0 col1" >PC1 (56.2%)</th>
#       <th id="T_061a0_level0_col2" class="col_heading level0 col2" >PC2 (7.4%)</th>
#       <th id="T_061a0_level0_col3" class="col_heading level0 col3" >PC3 (2.9%)</th>
#       <th id="T_061a0_level0_col4" class="col_heading level0 col4" >PC4 (2.8%)</th>
#       <th id="T_061a0_level0_col5" class="col_heading level0 col5" >PC5 (2.1%)</th>
#       <th id="T_061a0_level0_col6" class="col_heading level0 col6" >PC6 (1.7%)</th>
#       <th id="T_061a0_level0_col7" class="col_heading level0 col7" >PC7 (1.6%)</th>
#       <th id="T_061a0_level0_col8" class="col_heading level0 col8" >PC1 (56.2%)_abs_dif</th>
#       <th id="T_061a0_level0_col9" class="col_heading level0 col9" >PC2 (7.4%)_abs_dif</th>
#       <th id="T_061a0_level0_col10" class="col_heading level0 col10" >PC3 (2.9%)_abs_dif</th>
#       <th id="T_061a0_level0_col11" class="col_heading level0 col11" >PC4 (2.8%)_abs_dif</th>
#       <th id="T_061a0_level0_col12" class="col_heading level0 col12" >PC5 (2.1%)_abs_dif</th>
#       <th id="T_061a0_level0_col13" class="col_heading level0 col13" >PC6 (1.7%)_abs_dif</th>
#       <th id="T_061a0_level0_col14" class="col_heading level0 col14" >PC7 (1.6%)_abs_dif</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_061a0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_061a0_row0_col0" class="data row0 col0" >None</td>
#       <td id="T_061a0_row0_col1" class="data row0 col1" >0.052000</td>
#       <td id="T_061a0_row0_col2" class="data row0 col2" >-0.039000</td>
#       <td id="T_061a0_row0_col3" class="data row0 col3" >0.066000</td>
#       <td id="T_061a0_row0_col4" class="data row0 col4" >-0.021000</td>
#       <td id="T_061a0_row0_col5" class="data row0 col5" >-0.003000</td>
#       <td id="T_061a0_row0_col6" class="data row0 col6" >-0.023000</td>
#       <td id="T_061a0_row0_col7" class="data row0 col7" >0.041000</td>
#       <td id="T_061a0_row0_col8" class="data row0 col8" >0.007000</td>
#       <td id="T_061a0_row0_col9" class="data row0 col9" >0.010000</td>
#       <td id="T_061a0_row0_col10" class="data row0 col10" >0.036000</td>
#       <td id="T_061a0_row0_col11" class="data row0 col11" >0.003000</td>
#       <td id="T_061a0_row0_col12" class="data row0 col12" >0.002000</td>
#       <td id="T_061a0_row0_col13" class="data row0 col13" >0.019000</td>
#       <td id="T_061a0_row0_col14" class="data row0 col14" >0.043000</td>
#     </tr>
#     <tr>
#       <th id="T_061a0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_061a0_row1_col0" class="data row1 col0" >None</td>
#       <td id="T_061a0_row1_col1" class="data row1 col1" >0.052000</td>
#       <td id="T_061a0_row1_col2" class="data row1 col2" >-0.019000</td>
#       <td id="T_061a0_row1_col3" class="data row1 col3" >0.046000</td>
#       <td id="T_061a0_row1_col4" class="data row1 col4" >-0.046000</td>
#       <td id="T_061a0_row1_col5" class="data row1 col5" >0.015000</td>
#       <td id="T_061a0_row1_col6" class="data row1 col6" >0.004000</td>
#       <td id="T_061a0_row1_col7" class="data row1 col7" >0.020000</td>
#       <td id="T_061a0_row1_col8" class="data row1 col8" >0.007000</td>
#       <td id="T_061a0_row1_col9" class="data row1 col9" >0.011000</td>
#       <td id="T_061a0_row1_col10" class="data row1 col10" >0.015000</td>
#       <td id="T_061a0_row1_col11" class="data row1 col11" >0.028000</td>
#       <td id="T_061a0_row1_col12" class="data row1 col12" >0.016000</td>
#       <td id="T_061a0_row1_col13" class="data row1 col13" >0.008000</td>
#       <td id="T_061a0_row1_col14" class="data row1 col14" >0.021000</td>
#     </tr>
#     <tr>
#       <th id="T_061a0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_061a0_row2_col0" class="data row2 col0" >None</td>
#       <td id="T_061a0_row2_col1" class="data row2 col1" >0.045000</td>
#       <td id="T_061a0_row2_col2" class="data row2 col2" >-0.058000</td>
#       <td id="T_061a0_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_061a0_row2_col4" class="data row2 col4" >-0.087000</td>
#       <td id="T_061a0_row2_col5" class="data row2 col5" >-0.013000</td>
#       <td id="T_061a0_row2_col6" class="data row2 col6" >-0.007000</td>
#       <td id="T_061a0_row2_col7" class="data row2 col7" >0.032000</td>
#       <td id="T_061a0_row2_col8" class="data row2 col8" >0.001000</td>
#       <td id="T_061a0_row2_col9" class="data row2 col9" >0.028000</td>
#       <td id="T_061a0_row2_col10" class="data row2 col10" >0.031000</td>
#       <td id="T_061a0_row2_col11" class="data row2 col11" >0.069000</td>
#       <td id="T_061a0_row2_col12" class="data row2 col12" >0.012000</td>
#       <td id="T_061a0_row2_col13" class="data row2 col13" >0.003000</td>
#       <td id="T_061a0_row2_col14" class="data row2 col14" >0.034000</td>
#     </tr>
#     <tr>
#       <th id="T_061a0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_061a0_row3_col0" class="data row3 col0" >None</td>
#       <td id="T_061a0_row3_col1" class="data row3 col1" >0.052000</td>
#       <td id="T_061a0_row3_col2" class="data row3 col2" >-0.043000</td>
#       <td id="T_061a0_row3_col3" class="data row3 col3" >0.042000</td>
#       <td id="T_061a0_row3_col4" class="data row3 col4" >-0.012000</td>
#       <td id="T_061a0_row3_col5" class="data row3 col5" >0.002000</td>
#       <td id="T_061a0_row3_col6" class="data row3 col6" >0.006000</td>
#       <td id="T_061a0_row3_col7" class="data row3 col7" >0.025000</td>
#       <td id="T_061a0_row3_col8" class="data row3 col8" >0.006000</td>
#       <td id="T_061a0_row3_col9" class="data row3 col9" >0.013000</td>
#       <td id="T_061a0_row3_col10" class="data row3 col10" >0.012000</td>
#       <td id="T_061a0_row3_col11" class="data row3 col11" >0.006000</td>
#       <td id="T_061a0_row3_col12" class="data row3 col12" >0.003000</td>
#       <td id="T_061a0_row3_col13" class="data row3 col13" >0.010000</td>
#       <td id="T_061a0_row3_col14" class="data row3 col14" >0.027000</td>
#     </tr>
#     <tr>
#       <th id="T_061a0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_061a0_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_061a0_row4_col1" class="data row4 col1" >0.052000</td>
#       <td id="T_061a0_row4_col2" class="data row4 col2" >-0.051000</td>
#       <td id="T_061a0_row4_col3" class="data row4 col3" >0.062000</td>
#       <td id="T_061a0_row4_col4" class="data row4 col4" >0.004000</td>
#       <td id="T_061a0_row4_col5" class="data row4 col5" >-0.028000</td>
#       <td id="T_061a0_row4_col6" class="data row4 col6" >0.009000</td>
#       <td id="T_061a0_row4_col7" class="data row4 col7" >0.035000</td>
#       <td id="T_061a0_row4_col8" class="data row4 col8" >0.007000</td>
#       <td id="T_061a0_row4_col9" class="data row4 col9" >0.022000</td>
#       <td id="T_061a0_row4_col10" class="data row4 col10" >0.031000</td>
#       <td id="T_061a0_row4_col11" class="data row4 col11" >0.022000</td>
#       <td id="T_061a0_row4_col12" class="data row4 col12" >0.027000</td>
#       <td id="T_061a0_row4_col13" class="data row4 col13" >0.013000</td>
#       <td id="T_061a0_row4_col14" class="data row4 col14" >0.037000</td>
#     </tr>
#     <tr>
#       <th id="T_061a0_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_061a0_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_061a0_row5_col1" class="data row5 col1" >0.049000</td>
#       <td id="T_061a

# %% [markdown]
# Since ``dPULearn().fit()`` returns the fitted model, list comprehension can be utilized to create results for various settings of a ``n_componentes``. If given as a float > 0 and < 1, this parameter represents the percentage of total variance to be retained by principal component analysis (PCA).

# %%
list_labels = [dpul.fit(X=X, labels=labels, n_unl_to_neg=n_pos, n_components=i).labels_ for i in [0.6, 0.7, 0.8, 0.9, 0.95]]

# %% [markdown]
# As alternative to ``PCA-based identification`` of negatives, ``distance-based identification`` can be performed using distance metrics including 'euclidean', 'manhattan', or 'cosine' distance. A DataFrame with the

# %%
df_pu = dpul.fit(X=X, labels=labels, n_unl_to_neg=n_pos, metric="euclidean").df_pu_
aa.display_df(df_pu.sort_values(by="selection_via").head(100))
# Out:
# <style type="text/css">
# #T_6fa9f thead th {
#   background-color: white;
#   color: black;
# }
# #T_6fa9f tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_6fa9f tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_6fa9f th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_6fa9f  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_6fa9f table {
#   font-size: 12px;
# }
# </style>
# <table id="T_6fa9f" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fa9f_level0_col0" class="col_heading level0 col0" >selection_via</th>
#       <th id="T_6fa9f_level0_col1" class="col_heading level0 col1" >euclidean_dif</th>
#       <th id="T_6fa9f_level0_col2" class="col_heading level0 col2" >euclidean_abs_dif</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fa9f_level0_row0" class="row_heading level0 row0" >84</th>
#       <td id="T_6fa9f_row0_col0" class="data row0 col0" >euclidean</td>
#       <td id="T_6fa9f_row0_col1" class="data row0 col1" >3.481000</td>
#       <td id="T_6fa9f_row0_col2" class="data row0 col2" >3.481000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row1" class="row_heading level0 row1" >505</th>
#       <td id="T_6fa9f_row1_col0" class="data row1 col0" >euclidean</td>
#       <td id="T_6fa9f_row1_col1" class="data row1 col1" >3.233000</td>
#       <td id="T_6fa9f_row1_col2" class="data row1 col2" >3.233000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row2" class="row_heading level0 row2" >509</th>
#       <td id="T_6fa9f_row2_col0" class="data row2 col0" >euclidean</td>
#       <td id="T_6fa9f_row2_col1" class="data row2 col1" >3.336000</td>
#       <td id="T_6fa9f_row2_col2" class="data row2 col2" >3.336000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row3" class="row_heading level0 row3" >526</th>
#       <td id="T_6fa9f_row3_col0" class="data row3 col0" >euclidean</td>
#       <td id="T_6fa9f_row3_col1" class="data row3 col1" >3.390000</td>
#       <td id="T_6fa9f_row3_col2" class="data row3 col2" >3.390000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row4" class="row_heading level0 row4" >533</th>
#       <td id="T_6fa9f_row4_col0" class="data row4 col0" >euclidean</td>
#       <td id="T_6fa9f_row4_col1" class="data row4 col1" >3.364000</td>
#       <td id="T_6fa9f_row4_col2" class="data row4 col2" >3.364000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row5" class="row_heading level0 row5" >542</th>
#       <td id="T_6fa9f_row5_col0" class="data row5 col0" >euclidean</td>
#       <td id="T_6fa9f_row5_col1" class="data row5 col1" >3.075000</td>
#       <td id="T_6fa9f_row5_col2" class="data row5 col2" >3.075000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row6" class="row_heading level0 row6" >546</th>
#       <td id="T_6fa9f_row6_col0" class="data row6 col0" >euclidean</td>
#       <td id="T_6fa9f_row6_col1" class="data row6 col1" >3.162000</td>
#       <td id="T_6fa9f_row6_col2" class="data row6 col2" >3.162000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row7" class="row_heading level0 row7" >548</th>
#       <td id="T_6fa9f_row7_col0" class="data row7 col0" >euclidean</td>
#       <td id="T_6fa9f_row7_col1" class="data row7 col1" >3.112000</td>
#       <td id="T_6fa9f_row7_col2" class="data row7 col2" >3.112000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row8" class="row_heading level0 row8" >552</th>
#       <td id="T_6fa9f_row8_col0" class="data row8 col0" >euclidean</td>
#       <td id="T_6fa9f_row8_col1" class="data row8 col1" >3.289000</td>
#       <td id="T_6fa9f_row8_col2" class="data row8 col2" >3.289000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row9" class="row_heading level0 row9" >553</th>
#       <td id="T_6fa9f_row9_col0" class="data row9 col0" >euclidean</td>
#       <td id="T_6fa9f_row9_col1" class="data row9 col1" >3.621000</td>
#       <td id="T_6fa9f_row9_col2" class="data row9 col2" >3.621000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row10" class="row_heading level0 row10" >569</th>
#       <td id="T_6fa9f_row10_col0" class="data row10 col0" >euclidean</td>
#       <td id="T_6fa9f_row10_col1" class="data row10 col1" >3.280000</td>
#       <td id="T_6fa9f_row10_col2" class="data row10 col2" >3.280000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row11" class="row_heading level0 row11" >585</th>
#       <td id="T_6fa9f_row11_col0" class="data row11 col0" >euclidean</td>
#       <td id="T_6fa9f_row11_col1" class="data row11 col1" >3.369000</td>
#       <td id="T_6fa9f_row11_col2" class="data row11 col2" >3.369000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row12" class="row_heading level0 row12" >600</th>
#       <td id="T_6fa9f_row12_col0" class="data row12 col0" >euclidean</td>
#       <td id="T_6fa9f_row12_col1" class="data row12 col1" >3.278000</td>
#       <td id="T_6fa9f_row12_col2" class="data row12 col2" >3.278000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row13" class="row_heading level0 row13" >604</th>
#       <td id="T_6fa9f_row13_col0" class="data row13 col0" >euclidean</td>
#       <td id="T_6fa9f_row13_col1" class="data row13 col1" >3.369000</td>
#       <td id="T_6fa9f_row13_col2" class="data row13 col2" >3.369000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row14" class="row_heading level0 row14" >497</th>
#       <td id="T_6fa9f_row14_col0" class="data row14 col0" >euclidean</td>
#       <td id="T_6fa9f_row14_col1" class="data row14 col1" >3.311000</td>
#       <td id="T_6fa9f_row14_col2" class="data row14 col2" >3.311000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row15" class="row_heading level0 row15" >605</th>
#       <td id="T_6fa9f_row15_col0" class="data row15 col0" >euclidean</td>
#       <td id="T_6fa9f_row15_col1" class="data row15 col1" >3.153000</td>
#       <td id="T_6fa9f_row15_col2" class="data row15 col2" >3.153000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row16" class="row_heading level0 row16" >615</th>
#       <td id="T_6fa9f_row16_col0" class="data row16 col0" >euclidean</td>
#       <td id="T_6fa9f_row16_col1" class="data row16 col1" >3.270000</td>
#       <td id="T_6fa9f_row16_col2" class="data row16 col2" >3.270000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row17" class="row_heading level0 row17" >617</th>
#       <td id="T_6fa9f_row17_col0" class="data row17 col0" >euclidean</td>
#       <td id="T_6fa9f_row17_col1" class="data row17 col1" >3.146000</td>
#       <td id="T_6fa9f_row17_col2" class="data row17 col2" >3.146000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row18" class="row_heading level0 row18" >628</th>
#       <td id="T_6fa9f_row18_col0" class="data row18 col0" >euclidean</td>
#       <td id="T_6fa9f_row18_col1" class="data row18 col1" >3.214000</td>
#       <td id="T_6fa9f_row18_col2" class="data row18 col2" >3.214000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row19" class="row_heading level0 row19" >633</th>
#       <td id="T_6fa9f_row19_col0" class="data row19 col0" >euclidean</td>
#       <td id="T_6fa9f_row19_col1" class="data row19 col1" >3.192000</td>
#       <td id="T_6fa9f_row19_col2" class="data row19 col2" >3.192000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row20" class="row_heading level0 row20" >634</th>
#       <td id="T_6fa9f_row20_col0" class="data row20 col0" >euclidean</td>
#       <td id="T_6fa9f_row20_col1" class="data row20 col1" >3.158000</td>
#       <td id="T_6fa9f_row20_col2" class="data row20 col2" >3.158000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row21" class="row_heading level0 row21" >636</th>
#       <td id="T_6fa9f_row21_col0" class="data row21 col0" >euclidean</td>
#       <td id="T_6fa9f_row21_col1" class="data row21 col1" >3.173000</td>
#       <td id="T_6fa9f_row21_col2" class="data row21 col2" >3.173000</td>
#     </tr>
#     <tr>
#       <th id="T_6fa9f_level0_row22" class="row_heading level0 row22" >637</th>
#       <td id="T_6fa9f_row22_col0" class="data row22 col0" >euclidean</td>
#       <td id="T_6fa9f_row22_col1" class="data row22 col1" >3.122000</t

# %% [markdown]
# Using ``PCA-based identification``, 'df_pu' provides the principal component (PC) values for all used PC and offers a label indicating based on which PC the respective negative samples was identified on:

# %%
df_pu = dpul.fit(X=X, labels=labels, n_unl_to_neg=n_pos, n_components=0.8).df_pu_
aa.display_df(df_pu.sort_values(by="selection_via").head(100))
# Out:
# <style type="text/css">
# #T_2e31a thead th {
#   background-color: white;
#   color: black;
# }
# #T_2e31a tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_2e31a tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_2e31a th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_2e31a  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_2e31a table {
#   font-size: 12px;
# }
# </style>
# <table id="T_2e31a" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e31a_level0_col0" class="col_heading level0 col0" >selection_via</th>
#       <th id="T_2e31a_level0_col1" class="col_heading level0 col1" >PC1 (56.2%)</th>
#       <th id="T_2e31a_level0_col2" class="col_heading level0 col2" >PC2 (7.4%)</th>
#       <th id="T_2e31a_level0_col3" class="col_heading level0 col3" >PC3 (2.9%)</th>
#       <th id="T_2e31a_level0_col4" class="col_heading level0 col4" >PC4 (2.8%)</th>
#       <th id="T_2e31a_level0_col5" class="col_heading level0 col5" >PC5 (2.1%)</th>
#       <th id="T_2e31a_level0_col6" class="col_heading level0 col6" >PC6 (1.7%)</th>
#       <th id="T_2e31a_level0_col7" class="col_heading level0 col7" >PC7 (1.6%)</th>
#       <th id="T_2e31a_level0_col8" class="col_heading level0 col8" >PC1 (56.2%)_abs_dif</th>
#       <th id="T_2e31a_level0_col9" class="col_heading level0 col9" >PC2 (7.4%)_abs_dif</th>
#       <th id="T_2e31a_level0_col10" class="col_heading level0 col10" >PC3 (2.9%)_abs_dif</th>
#       <th id="T_2e31a_level0_col11" class="col_heading level0 col11" >PC4 (2.8%)_abs_dif</th>
#       <th id="T_2e31a_level0_col12" class="col_heading level0 col12" >PC5 (2.1%)_abs_dif</th>
#       <th id="T_2e31a_level0_col13" class="col_heading level0 col13" >PC6 (1.7%)_abs_dif</th>
#       <th id="T_2e31a_level0_col14" class="col_heading level0 col14" >PC7 (1.6%)_abs_dif</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e31a_level0_row0" class="row_heading level0 row0" >497</th>
#       <td id="T_2e31a_row0_col0" class="data row0 col0" >PC1</td>
#       <td id="T_2e31a_row0_col1" class="data row0 col1" >0.022000</td>
#       <td id="T_2e31a_row0_col2" class="data row0 col2" >0.051000</td>
#       <td id="T_2e31a_row0_col3" class="data row0 col3" >-0.013000</td>
#       <td id="T_2e31a_row0_col4" class="data row0 col4" >0.016000</td>
#       <td id="T_2e31a_row0_col5" class="data row0 col5" >-0.060000</td>
#       <td id="T_2e31a_row0_col6" class="data row0 col6" >0.064000</td>
#       <td id="T_2e31a_row0_col7" class="data row0 col7" >-0.070000</td>
#       <td id="T_2e31a_row0_col8" class="data row0 col8" >0.023000</td>
#       <td id="T_2e31a_row0_col9" class="data row0 col9" >0.081000</td>
#       <td id="T_2e31a_row0_col10" class="data row0 col10" >0.044000</td>
#       <td id="T_2e31a_row0_col11" class="data row0 col11" >0.034000</td>
#       <td id="T_2e31a_row0_col12" class="data row0 col12" >0.060000</td>
#       <td id="T_2e31a_row0_col13" class="data row0 col13" >0.067000</td>
#       <td id="T_2e31a_row0_col14" class="data row0 col14" >0.068000</td>
#     </tr>
#     <tr>
#       <th id="T_2e31a_level0_row1" class="row_heading level0 row1" >615</th>
#       <td id="T_2e31a_row1_col0" class="data row1 col0" >PC1</td>
#       <td id="T_2e31a_row1_col1" class="data row1 col1" >0.026000</td>
#       <td id="T_2e31a_row1_col2" class="data row1 col2" >0.053000</td>
#       <td id="T_2e31a_row1_col3" class="data row1 col3" >-0.099000</td>
#       <td id="T_2e31a_row1_col4" class="data row1 col4" >0.002000</td>
#       <td id="T_2e31a_row1_col5" class="data row1 col5" >0.001000</td>
#       <td id="T_2e31a_row1_col6" class="data row1 col6" >0.027000</td>
#       <td id="T_2e31a_row1_col7" class="data row1 col7" >0.005000</td>
#       <td id="T_2e31a_row1_col8" class="data row1 col8" >0.020000</td>
#       <td id="T_2e31a_row1_col9" class="data row1 col9" >0.083000</td>
#       <td id="T_2e31a_row1_col10" class="data row1 col10" >0.130000</td>
#       <td id="T_2e31a_row1_col11" class="data row1 col11" >0.019000</td>
#       <td id="T_2e31a_row1_col12" class="data row1 col12" >0.001000</td>
#       <td id="T_2e31a_row1_col13" class="data row1 col13" >0.031000</td>
#       <td id="T_2e31a_row1_col14" class="data row1 col14" >0.007000</td>
#     </tr>
#     <tr>
#       <th id="T_2e31a_level0_row2" class="row_heading level0 row2" >406</th>
#       <td id="T_2e31a_row2_col0" class="data row2 col0" >PC1</td>
#       <td id="T_2e31a_row2_col1" class="data row2 col1" >0.025000</td>
#       <td id="T_2e31a_row2_col2" class="data row2 col2" >0.031000</td>
#       <td id="T_2e31a_row2_col3" class="data row2 col3" >-0.027000</td>
#       <td id="T_2e31a_row2_col4" class="data row2 col4" >-0.010000</td>
#       <td id="T_2e31a_row2_col5" class="data row2 col5" >0.052000</td>
#       <td id="T_2e31a_row2_col6" class="data row2 col6" >-0.002000</td>
#       <td id="T_2e31a_row2_col7" class="data row2 col7" >-0.009000</td>
#       <td id="T_2e31a_row2_col8" class="data row2 col8" >0.020000</td>
#       <td id="T_2e31a_row2_col9" class="data row2 col9" >0.061000</td>
#       <td id="T_2e31a_row2_col10" class="data row2 col10" >0.058000</td>
#       <td id="T_2e31a_row2_col11" class="data row2 col11" >0.007000</td>
#       <td id="T_2e31a_row2_col12" class="data row2 col12" >0.052000</td>
#       <td id="T_2e31a_row2_col13" class="data row2 col13" >0.002000</td>
#       <td id="T_2e31a_row2_col14" class="data row2 col14" >0.007000</td>
#     </tr>
#     <tr>
#       <th id="T_2e31a_level0_row3" class="row_heading level0 row3" >446</th>
#       <td id="T_2e31a_row3_col0" class="data row3 col0" >PC1</td>
#       <td id="T_2e31a_row3_col1" class="data row3 col1" >0.026000</td>
#       <td id="T_2e31a_row3_col2" class="data row3 col2" >0.014000</td>
#       <td id="T_2e31a_row3_col3" class="data row3 col3" >-0.054000</td>
#       <td id="T_2e31a_row3_col4" class="data row3 col4" >-0.062000</td>
#       <td id="T_2e31a_row3_col5" class="data row3 col5" >0.024000</td>
#       <td id="T_2e31a_row3_col6" class="data row3 col6" >-0.019000</td>
#       <td id="T_2e31a_row3_col7" class="data row3 col7" >-0.054000</td>
#       <td id="T_2e31a_row3_col8" class="data row3 col8" >0.019000</td>
#       <td id="T_2e31a_row3_col9" class="data row3 col9" >0.044000</td>
#       <td id="T_2e31a_row3_col10" class="data row3 col10" >0.085000</td>
#       <td id="T_2e31a_row3_col11" class="data row3 col11" >0.044000</td>
#       <td id="T_2e31a_row3_col12" class="data row3 col12" >0.024000</td>
#       <td id="T_2e31a_row3_col13" class="data row3 col13" >0.015000</td>
#       <td id="T_2e31a_row3_col14" class="data row3 col14" >0.052000</td>
#     </tr>
#     <tr>
#       <th id="T_2e31a_level0_row4" class="row_heading level0 row4" >455</th>
#       <td id="T_2e31a_row4_col0" class="data row4 col0" >PC1</td>
#       <td id="T_2e31a_row4_col1" class="data row4 col1" >0.027000</td>
#       <td id="T_2e31a_row4_col2" class="data row4 col2" >0.052000</td>
#       <td id="T_2e31a_row4_col3" class="data row4 col3" >-0.090000</td>
#       <td id="T_2e31a_row4_col4" class="data row4 col4" >-0.045000</td>
#       <td id="T_2e31a_row4_col5" class="data row4 col5" >-0.073000</td>
#       <td id="T_2e31a_row4_col6" class="data row4 col6" >0.029000</td>
#       <td id="T_2e31a_row4_col7" class="data row4 col7" >0.061000</td>
#       <td id="T_2e31a_row4_col8" class="data row4 col8" >0.019000</td>
#       <td id="T_2e31a_row4_col9" class="data row4 col9" >0.082000</td>
#       <td id="T_2e31a_row4_col10" class="data row4 col10" >0.120000</td>
#       <td id="T_2e31a_row4_col11" class="data row4 col11" >0.027000</td>
#       <td id="T_2e31a_row4_col12" class="data row4 col12" >0.072000</td>
#       <td id="T_2e31a_row4_col13" class="data row4 col13" >0.033000</td>
#       <td id="T_2e31a_row4_col14" class="data row4 col14" >0.063000</td>
#     </tr>
#     <tr>
#       <th id="T_2e31a_level0_row5" class="row_heading level0 row5" >468</th>
#       <td id="T_2e31a_row5_col0" class="data row5 col0" >PC1</td>
#       <td id="T_2e31a_row5_col1" class="data row5 col1" >0.026000</td>
#       <td id=
