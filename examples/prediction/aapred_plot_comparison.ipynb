# %% [markdown]
# To demonstrate ``AAPredPlot().comparison()``, we build a tidy benchmark frame comparing a scale-based baseline against CPP across two data conditions:

# %%
import pandas as pd
import aaanalysis as aa
aa.options["verbose"] = False

df_eval = pd.DataFrame({
    "group":     ["Scale-based", "Scale-based", "CPP", "CPP"],
    "condition": ["Substrate", "Non-substrate", "Substrate", "Non-substrate"],
    "value":     [61, 60, 71, 74],
})
aa.display_df(df_eval, n_rows=10, show_shape=True)
# Out:
# DataFrame shape: (4, 3)
# <style type="text/css">
# #T_d720b thead th {
#   background-color: white;
#   color: black;
# }
# #T_d720b tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_d720b tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_d720b th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_d720b  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_d720b" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d720b_level0_col0" class="col_heading level0 col0" >group</th>
#       <th id="T_d720b_level0_col1" class="col_heading level0 col1" >condition</th>
#       <th id="T_d720b_level0_col2" class="col_heading level0 col2" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d720b_level0_row0" class="row_heading level0 row0" >1</th>
# ...

# %% [markdown]
# Each condition is an x-axis cluster, each group a colored bar, with per-bar value labels and a dashed chance line:

# %%
import matplotlib.pyplot as plt
aa.plot_settings()
aa.AAPredPlot().comparison(df_eval, baseline=50, ylabel="Balanced accuracy [%]")
plt.tight_layout()
plt.show()
