# %% [markdown]
# You can retrieve a list of n colors by using the 'n_colors' parameter:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import aaanalysis as aa
colors = aa.plot_get_clist(n_colors=3)
sns.palplot(colors)
plt.show()

# %% [markdown]
# We assembled 8 different color lists for 2 to 9 colors:

# %%
for n in range(2, 9):
    colors = aa.plot_get_clist(n_colors=n)
    sns.palplot(colors)
    plt.show()

# %% [markdown]
# For more than 9 colors, we provide the 'husl' default color palette of the :func:`seaborn.color_palette` fuction:

# %%
for n in [10, 15, 20, 50]:
    colors = aa.plot_get_clist(n_colors=n)
    sns.palplot(colors)
    plt.show()
