# %% [markdown]
# You can read FASTA files using the ``read_fasta()`` function:

# %%
import aaanalysis as aa
file_path = "data/example_FASTA.fasta"
df_seq = aa.read_fasta(file_path)
aa.display_df(df_seq, n_rows=4)
# Out:
# <style type="text/css">
# #T_a3704 thead th {
#   background-color: white;
#   color: black;
# }
# #T_a3704 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_a3704 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_a3704 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_a3704  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_a3704" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3704_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_a3704_level0_col1" class="col_heading level0 col1" >sequence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3704_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a3704_row0_col0" class="data row0 col0" >SEMA4A,38.4</td>
#       <td id="T_a3704_row0_col1" class="data row0 col1" >LAAQQSYWPHFVTVT...IILVASPLRALRARG</td>
#     </tr>
#     <tr>
#       <th id="T_a3704_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a3704_row1_col0" class="data row1 col0" >SEMA4B,47.0</td>
#       <td id="T_a3704_row1_col1" class="data row1 col1" >WGADRSYWKEFLVMC...LFLLYRHRNSMKVFL</td>
#     </tr>
#     <tr>
#       <th id="T_a3704_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a3704_row2_col0" class="data row2 col0" >SEMA4C,86.6</td>
#       <td id="T_a3704_row2_col1" class="data row2 col1" >EARAPLENLGLVWLA...LLLVLSLRRRLREEL</td>
#     </tr>
#     <tr>
#       <th id="T_a3704_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a3704_row3_col0" class="data row3 col0" >SEMA4D,19.1</td>
#       <td id="T_a3704_row3_col1" class="data row3 col1" >TMYLKSSDNRLLMSL...FFYNCYKGYLPRQCL</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To adjust the names of the columns for the primary FASTA file information, use the ``col_id`` and ``col_seq`` parameters:

# %%
df_seq = aa.read_fasta(file_path, col_id="ENTRY", col_seq="SEQUENCE")
aa.display_df(df_seq, n_rows=4)
# Out:
# <style type="text/css">
# #T_b4e89 thead th {
#   background-color: white;
#   color: black;
# }
# #T_b4e89 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_b4e89 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_b4e89 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_b4e89  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_b4e89" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4e89_level0_col0" class="col_heading level0 col0" >ENTRY</th>
#       <th id="T_b4e89_level0_col1" class="col_heading level0 col1" >SEQUENCE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e89_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b4e89_row0_col0" class="data row0 col0" >SEMA4A,38.4</td>
#       <td id="T_b4e89_row0_col1" class="data row0 col1" >LAAQQSYWPHFVTVT...IILVASPLRALRARG</td>
#     </tr>
#     <tr>
#       <th id="T_b4e89_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b4e89_row1_col0" class="data row1 col0" >SEMA4B,47.0</td>
#       <td id="T_b4e89_row1_col1" class="data row1 col1" >WGADRSYWKEFLVMC...LFLLYRHRNSMKVFL</td>
#     </tr>
#     <tr>
#       <th id="T_b4e89_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b4e89_row2_col0" class="data row2 col0" >SEMA4C,86.6</td>
#       <td id="T_b4e89_row2_col1" class="data row2 col1" >EARAPLENLGLVWLA...LLLVLSLRRRLREEL</td>
#     </tr>
#     <tr>
#       <th id="T_b4e89_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b4e89_row3_col0" class="data row3 col0" >SEMA4D,19.1</td>
#       <td id="T_b4e89_row3_col1" class="data row3 col1" >TMYLKSSDNRLLMSL...FFYNCYKGYLPRQCL</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The ``col_id`` column should only contain the unique identifier. If the FASTA file comprises additional information, use the ``sep`` (default='|') argument to save them in additional columns, named ``info1`` to ``info(n)``:

# %%
df_seq = aa.read_fasta(file_path, sep=",")
aa.display_df(df_seq, n_rows=4)
# Out:
# <style type="text/css">
# #T_15dd5 thead th {
#   background-color: white;
#   color: black;
# }
# #T_15dd5 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_15dd5 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_15dd5 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_15dd5  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_15dd5" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15dd5_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_15dd5_level0_col1" class="col_heading level0 col1" >sequence</th>
#       <th id="T_15dd5_level0_col2" class="col_heading level0 col2" >info1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15dd5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_15dd5_row0_col0" class="data row0 col0" >SEMA4A</td>
#       <td id="T_15dd5_row0_col1" class="data row0 col1" >LAAQQSYWPHFVTVT...IILVASPLRALRARG</td>
#       <td id="T_15dd5_row0_col2" class="data row0 col2" >38.4</td>
#     </tr>
#     <tr>
#       <th id="T_15dd5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_15dd5_row1_col0" class="data row1 col0" >SEMA4B</td>
#       <td id="T_15dd5_row1_col1" class="data row1 col1" >WGADRSYWKEFLVMC...LFLLYRHRNSMKVFL</td>
#       <td id="T_15dd5_row1_col2" class="data row1 col2" >47.0</td>
#     </tr>
#     <tr>
#       <th id="T_15dd5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_15dd5_row2_col0" class="data row2 col0" >SEMA4C</td>
#       <td id="T_15dd5_row2_col1" class="data row2 col1" >EARAPLENLGLVWLA...LLLVLSLRRRLREEL</td>
#       <td id="T_15dd5_row2_col2" class="data row2 col2" >86.6</td>
#     </tr>
#     <tr>
#       <th id="T_15dd5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_15dd5_row3_col0" class="data row3 col0" >SEMA4D</td>
#       <td id="T_15dd5_row3_col1" class="data row3 col1" >TMYLKSSDNRLLMSL...FFYNCYKGYLPRQCL</td>
#       <td id="T_15dd5_row3_col2" class="data row3 col2" >19.1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To adjust the name of the additional columns, provide a list of column names by ``cols_info``:

# %%
df_seq = aa.read_fasta(file_path, sep=",", cols_info=["prediction"])
aa.display_df(df_seq, n_rows=4)
# Out:
# <style type="text/css">
# #T_cf7d5 thead th {
#   background-color: white;
#   color: black;
# }
# #T_cf7d5 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_cf7d5 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_cf7d5 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_cf7d5  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_cf7d5" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf7d5_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_cf7d5_level0_col1" class="col_heading level0 col1" >sequence</th>
#       <th id="T_cf7d5_level0_col2" class="col_heading level0 col2" >prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf7d5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_cf7d5_row0_col0" class="data row0 col0" >SEMA4A</td>
#       <td id="T_cf7d5_row0_col1" class="data row0 col1" >LAAQQSYWPHFVTVT...IILVASPLRALRARG</td>
#       <td id="T_cf7d5_row0_col2" class="data row0 col2" >38.4</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_cf7d5_row1_col0" class="data row1 col0" >SEMA4B</td>
#       <td id="T_cf7d5_row1_col1" class="data row1 col1" >WGADRSYWKEFLVMC...LFLLYRHRNSMKVFL</td>
#       <td id="T_cf7d5_row1_col2" class="data row1 col2" >47.0</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cf7d5_row2_col0" class="data row2 col0" >SEMA4C</td>
#       <td id="T_cf7d5_row2_col1" class="data row2 col1" >EARAPLENLGLVWLA...LLLVLSLRRRLREEL</td>
#       <td id="T_cf7d5_row2_col2" class="data row2 col2" >86.6</td>
#     </tr>
#     <tr>
#       <th id="T_cf7d5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_cf7d5_row3_col0" class="data row3 col0" >SEMA4D</td>
#       <td id="T_cf7d5_row3_col1" class="data row3 col1" >TMYLKSSDNRLLMSL...FFYNCYKGYLPRQCL</td>
#       <td id="T_cf7d5_row3_col2" class="data row3 col2" >19.1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The headers of FASTA files can start with a database abbreviation (e.g., 'sp' for Swiss-Prot). To properly convert these into a database column, provide a name to the ``col_db`` parameter:

# %%
file_path = "data/example_FASTA_db.fasta"
df_seq = aa.read_fasta(file_path, col_db="database", sep=",")
aa.display_df(df_seq, n_rows=4)
# Out:
# <style type="text/css">
# #T_341e6 thead th {
#   background-color: white;
#   color: black;
# }
# #T_341e6 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_341e6 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_341e6 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_341e6  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_341e6" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_341e6_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_341e6_level0_col1" class="col_heading level0 col1" >sequence</th>
#       <th id="T_341e6_level0_col2" class="col_heading level0 col2" >database</th>
#       <th id="T_341e6_level0_col3" class="col_heading level0 col3" >info1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_341e6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_341e6_row0_col0" class="data row0 col0" >SEMA4A</td>
#       <td id="T_341e6_row0_col1" class="data row0 col1" >LAAQQSYWPHFVTVT...IILVASPLRALRARG</td>
#       <td id="T_341e6_row0_col2" class="data row0 col2" >sp</td>
#       <td id="T_341e6_row0_col3" class="data row0 col3" >38.4</td>
#     </tr>
#     <tr>
#       <th id="T_341e6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_341e6_row1_col0" class="data row1 col0" >SEMA4B</td>
#       <td id="T_341e6_row1_col1" class="data row1 col1" >WGADRSYWKEFLVMC...LFLLYRHRNSMKVFL</td>
#       <td id="T_341e6_row1_col2" class="data row1 col2" >sp</td>
#       <td id="T_341e6_row1_col3" class="data row1 col3" >47.0</td>
#     </tr>
#     <tr>
#       <th id="T_341e6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_341e6_row2_col0" class="data row2 col0" >SEMA4C</td>
#       <td id="T_341e6_row2_col1" class="data row2 col1" >EARAPLENLGLVWLA...LLLVLSLRRRLREEL</td>
#       <td id="T_341e6_row2_col2" class="data row2 col2" >sp</td>
#       <td id="T_341e6_row2_col3" class="data row2 col3" >86.6</td>
#     </tr>
#     <tr>
#       <th id="T_341e6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_341e6_row3_col0" class="data row3 col0" >SEMA4D</td>
#       <td id="T_341e6_row3_col1" class="data row3 col1" >TMYLKSSDNRLLMSL...FFYNCYKGYLPRQCL</td>
#       <td id="T_341e6_row3_col2" class="data row3 col2" >sp</td>
#       <td id="T_341e6_row3_col3" class="data row3 col3" >19.1</td>
#     </tr>
#   </tbody>
# </table>
