# %% [markdown]
# To demonstrate integer encoding of protein sequences using the ``SequencePreprocessor().encode_integer()`` method, we first create an example sequence:

# %%
import aaanalysis as aa
import pandas as pd

list_seq = ["AACDEFGHIY", "IIHGFECDAY"]
seqp = aa.SequencePreprocessor()

# %% [markdown]
# Provide the sequence as ``seq`` parameter to obtain a feature matrix (``X``) and the respective ``features``, which are integer amino acid representation at given residue positions:

# %%
X, features = seqp.encode_integer(list_seq=list_seq)

# Convert to DataFrame for visualization
df_encode = pd.DataFrame(X, columns=features, index=list_seq)
aa.display_df(df=df_encode, show_shape=True)
# Out:
# DataFrame shape: (2, 10)
# <style type="text/css">
# #T_19967 thead th {
#   background-color: white;
#   color: black;
# }
# #T_19967 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_19967 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_19967 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_19967  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_19967" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19967_level0_col0" class="col_heading level0 col0" >P1</th>
#       <th id="T_19967_level0_col1" class="col_heading level0 col1" >P2</th>
#       <th id="T_19967_level0_col2" class="col_heading level0 col2" >P3</th>
#       <th id="T_19967_level0_col3" class="col_heading level0 col3" >P4</th>
#       <th id="T_19967_level0_col4" class="col_heading level0 col4" >P5</th>
#       <th id="T_19967_level0_col5" class="col_heading level0 col5" >P6</th>
#       <th id="T_19967_level0_col6" class="col_heading level0 col6" >P7</th>
#       <th id="T_19967_level0_col7" class="col_heading level0 col7" >P8</th>
#       <th id="T_19967_level0_col8" class="col_heading level0 col8" >P9</th>
#       <th id="T_19967_level0_col9" class="col_heading level0 col9" >P10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19967_level0_row0" class="row_heading level0 row0" >AACDEFGHIY</th>
#       <td id="T_19967_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_19967_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_19967_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_19967_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_19967_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_19967_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_19967_row0_col6" class="data row0 col6" >6</td>
#       <td id="T_19967_row0_col7" class="data row0 col7" >7</td>
#       <td id="T_19967_row0_col8" class="data row0 col8" >8</td>
#       <td id="T_19967_row0_col9" class="data row0 col9" >20</td>
#     </tr>
#     <tr>
#       <th id="T_19967_level0_row1" class="row_heading level0 row1" >IIHGFECDAY</th>
#       <td id="T_19967_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_19967_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_19967_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_19967_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_19967_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_19967_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_19967_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_19967_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_19967_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_19967_row1_col9" class="data row1 col9" >20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can adjust the used ``alphabet`` to change the considered characters:

# %%
# Show integer encoding with smaller alphabet
list_seq = ["ABC", "CBA"]
ALPHABET = "ABC"
X, features = seqp.encode_integer(list_seq=list_seq, alphabet=ALPHABET)

# Convert to DataFrame for visualization
df_encode = pd.DataFrame(X, columns=features, index=list_seq)
aa.display_df(df=df_encode, show_shape=True)
# Out:
# DataFrame shape: (2, 3)
# <style type="text/css">
# #T_04508 thead th {
#   background-color: white;
#   color: black;
# }
# #T_04508 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_04508 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_04508 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_04508  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_04508" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04508_level0_col0" class="col_heading level0 col0" >P1</th>
#       <th id="T_04508_level0_col1" class="col_heading level0 col1" >P2</th>
#       <th id="T_04508_level0_col2" class="col_heading level0 col2" >P3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04508_level0_row0" class="row_heading level0 row0" >ABC</th>
#       <td id="T_04508_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_04508_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_04508_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_04508_level0_row1" class="row_heading level0 row1" >CBA</th>
#       <td id="T_04508_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_04508_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_04508_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Change the ``gap`` symbol (default=``-``) as follows:

# %%
# Show integer encoding with other gap ('*')
list_seq = ["ABC", "CB*"]
ALPHABET = "ABC"
X, features = seqp.encode_integer(list_seq=list_seq, alphabet=ALPHABET, gap="*")

# Convert to DataFrame for visualization
df_encode = pd.DataFrame(X, columns=features, index=list_seq)
aa.display_df(df=df_encode, show_shape=True)
# Out:
# DataFrame shape: (2, 3)
# <style type="text/css">
# #T_cd263 thead th {
#   background-color: white;
#   color: black;
# }
# #T_cd263 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_cd263 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_cd263 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_cd263  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_cd263" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd263_level0_col0" class="col_heading level0 col0" >P1</th>
#       <th id="T_cd263_level0_col1" class="col_heading level0 col1" >P2</th>
#       <th id="T_cd263_level0_col2" class="col_heading level0 col2" >P3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd263_level0_row0" class="row_heading level0 row0" >ABC</th>
#       <td id="T_cd263_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cd263_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_cd263_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cd263_level0_row1" class="row_heading level0 row1" >CB*</th>
#       <td id="T_cd263_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_cd263_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_cd263_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If one sequence is smaller than the other, gaps will be included either at the N-terminus or C-terminus (default), which is called padding. Adjust the padding using the ``pad_at`` (``N`` or ``C``) parameter:

# %%
# Show default padding (at C-Termius)
list_seq = ["ABC", "B"]
ALPHABET = "ABC"
X, features = seqp.encode_integer(list_seq=list_seq, alphabet=ALPHABET)

# Convert to DataFrame for visualization
df_encode = pd.DataFrame(X, columns=features, index=list_seq)
aa.display_df(df=df_encode, show_shape=True)
# Out:
# DataFrame shape: (2, 3)
# <style type="text/css">
# #T_76b77 thead th {
#   background-color: white;
#   color: black;
# }
# #T_76b77 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_76b77 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_76b77 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_76b77  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_76b77" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76b77_level0_col0" class="col_heading level0 col0" >P1</th>
#       <th id="T_76b77_level0_col1" class="col_heading level0 col1" >P2</th>
#       <th id="T_76b77_level0_col2" class="col_heading level0 col2" >P3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76b77_level0_row0" class="row_heading level0 row0" >ABC</th>
#       <td id="T_76b77_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_76b77_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_76b77_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_76b77_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_76b77_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_76b77_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_76b77_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Show N-terminal padding
list_seq = ["ABC", "B"]
ALPHABET = "ABC"
X, features = seqp.encode_integer(list_seq=list_seq, alphabet=ALPHABET, pad_at="N")

# Convert to DataFrame for visualization
df_encode = pd.DataFrame(X, columns=features, index=list_seq)
aa.display_df(df=df_encode, show_shape=True)
# Out:
# DataFrame shape: (2, 3)
# <style type="text/css">
# #T_2f9f1 thead th {
#   background-color: white;
#   color: black;
# }
# #T_2f9f1 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_2f9f1 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_2f9f1 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_2f9f1  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_2f9f1" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f9f1_level0_col0" class="col_heading level0 col0" >P1</th>
#       <th id="T_2f9f1_level0_col1" class="col_heading level0 col1" >P2</th>
#       <th id="T_2f9f1_level0_col2" class="col_heading level0 col2" >P3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f9f1_level0_row0" class="row_heading level0 row0" >ABC</th>
#       <td id="T_2f9f1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2f9f1_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2f9f1_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2f9f1_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_2f9f1_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_2f9f1_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2f9f1_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#   </tbody>
# </table>
