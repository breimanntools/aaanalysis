# %% [markdown]
# You can load features corresponding to a specific dataset using the ``load_feature()`` function:

# %%
import aaanalysis as aa
df_feat = aa.load_features(name="DOM_GSEC")
aa.display_df(df_feat, show_shape=True)
# Out:
# DataFrame shape: (150, 15)
# <style type="text/css">
# #T_d981b thead th {
#   background-color: white;
#   color: black;
# }
# #T_d981b tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_d981b tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_d981b th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_d981b  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_d981b" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d981b_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_d981b_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_d981b_level0_col2" class="col_heading level0 col2" >subcategory</th>
#       <th id="T_d981b_level0_col3" class="col_heading level0 col3" >scale_name</th>
# ...

# %% [markdown]
# Feature sets are made available for datasets that have been rigorously tested and documented through scientific research.
