# %% [markdown]
# The ``aaanalysis.pipe`` (``ap``) module provides high-level **golden pipelines** — stateless, one-call wrappers over the AAanalysis primitives. ``ap.predict_samples`` trains and compares predictors across one or more **feature sets** and **scikit-learn models**: for every (feature set × model) combination it rebuilds the feature matrix, cross-validates the model, and refits it on all samples. It returns the uniform pipeline triple ``(predictors, ax, df_eval)`` — a dict of fitted predictors keyed by ``(feature_set, model)``, ``ax`` (the model comparison plot, or ``None`` with ``plot=False``), and a tidy cross-validated comparison table (see [Breimann25]_).
#
# We first load the ``DOM_GSEC`` example dataset, its labels, and a small feature set:

# %%
import aaanalysis as aa
import aaanalysis.pipe as ap
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import warnings
aa.options["verbose"] = False
# Newer scikit-learn releases deprecate SVC(probability=True), used by the default SVM model;
# silence that notice so the example output stays focused on the comparison.
warnings.filterwarnings("ignore", message=".*probability.*", category=FutureWarning)

df_seq = aa.load_dataset(name="DOM_GSEC", n=25)
labels = df_seq["label"].to_list()
df_feat = aa.load_features().head(10)

aa.display_df(df_feat, n_rows=10, show_shape=True)
# Out:
# DataFrame shape: (10, 15)
# <style type="text/css">
# #T_0dec3 thead th {
#   background-color: white;
#   color: black;
# }
# #T_0dec3 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_0dec3 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_0dec3 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_0dec3  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_0dec3" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dec3_level0_col0" class="col_heading level0 col0" >feature</th>
#       <th id="T_0dec3_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_0dec3_level0_col2" class="col_heading level0 col2" >subcategory</th>
#       <th id="T_0dec3_level0_col3" class="col_heading level0 col3" >scale_name</th>
# ...

# %% [markdown]
# **Default comparison.** With ``models=None`` a core set of four scikit-learn models is compared. With ``plot=True`` (the default) ``predict_samples`` also draws the model comparison bar plot (hue = model, one bar group per metric, with cross-validation ``std`` error bars) and returns its ``Axes``:

# %%
# plot=True (default) draws the model comparison and returns its Axes in the middle slot.
predictors, ax, df_eval = ap.predict_samples(list_df_feat=df_feat, df_seq=df_seq, labels=labels,
                                             random_state=42)
aa.display_df(df_eval, n_rows=10, show_shape=True)
plt.tight_layout()
plt.show()
# Out:
# DataFrame shape: (4, 17)
# <style type="text/css">
# #T_c62ba thead th {
#   background-color: white;
#   color: black;
# }
# #T_c62ba tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_c62ba tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_c62ba th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_c62ba  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_c62ba" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c62ba_level0_col0" class="col_heading level0 col0" >feature_set</th>
#       <th id="T_c62ba_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_c62ba_level0_col2" class="col_heading level0 col2" >n_features</th>
#       <th id="T_c62ba_level0_col3" class="col_heading level0 col3" >balanced_accuracy_mean</th>
# ...

# %% [markdown]
# **Reading ``df_eval``.** One row per ``(feature_set, model)``:
#
# - ``feature_set`` / ``model`` — the combination's names (also the keys of the returned ``predictors`` dict).
# - ``n_features`` — the number of features in that set.
# - ``<metric>_mean`` / ``<metric>_std`` — the cross-validated mean and standard deviation of each metric: ``balanced_accuracy`` (the headline, imbalance-aware), ``accuracy``, ``f1``, ``precision``, ``recall``, ``roc_auc``.
# - ``is_shap_ready`` — whether the fitted predictor exposes feature importances (tree-based models), so it can feed ``ap.explain_features``.
# - ``is_best`` — the single highest ``balanced_accuracy_mean`` row.
#
# The returned ``predictors`` is a dict keyed by ``(feature_set, model)``; pick the best one by its ``is_best`` row:

# %%
best = df_eval[df_eval["is_best"]].iloc[0]
print(f"best: {best['feature_set']} x {best['model']}  "
      f"(bACC={best['balanced_accuracy_mean']:.3f})")
print("predictor keys:", list(predictors))
best_predictor = predictors[(best["feature_set"], best["model"])]
print("best predictor:", type(best_predictor).__name__)
# Out:
# best: features x SVM  (bACC=0.820)
# predictor keys: [('features', 'RandomForest'), ('features', 'ExtraTrees'), ('features', 'SVM'), ('features', 'LogReg')]
# best predictor: SVC

# %% [markdown]
# **Choosing the models.** ``models`` accepts model-name strings (``'rf'``, ``'svm'``, ``'log_reg'``, ``'extra_trees'``), estimator instances, or a ``{name: model}`` dict. The comparison plot is styled with ``figsize``, a per-model ``dict_color``, and a ``baseline`` chance line:

# %%
# The comparison plot is styled with figsize, dict_color (keyed by model name) and a baseline line.
predictors, ax, df_eval = ap.predict_samples(
    df_feat, df_seq, labels=labels,
    models={"forest": "rf", "svc_rbf": SVC(C=2.0, probability=True),
            "logreg": LogisticRegression(max_iter=500)},
    n_cv=4, random_state=42, figsize=(7, 4), baseline=0.5,
    dict_color={"forest": "tab:green", "svc_rbf": "tab:blue", "logreg": "tab:orange"})

aa.display_df(df_eval, n_rows=10, show_shape=True)
plt.tight_layout()
plt.show()
# Out:
# DataFrame shape: (3, 17)
# <style type="text/css">
# #T_f7da0 thead th {
#   background-color: white;
#   color: black;
# }
# #T_f7da0 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_f7da0 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_f7da0 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_f7da0  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_f7da0" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7da0_level0_col0" class="col_heading level0 col0" >feature_set</th>
#       <th id="T_f7da0_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_f7da0_level0_col2" class="col_heading level0 col2" >n_features</th>
#       <th id="T_f7da0_level0_col3" class="col_heading level0 col3" >balanced_accuracy_mean</th>
# ...

# %% [markdown]
# **Comparing feature sets.** Pass several feature sets as a ``{name: df_feat}`` dict (or a list); every feature set is crossed with every model. This is the natural way to ask *which feature set and which model* work best together — e.g. a full versus a reduced feature set. ``n_jobs`` sets the cores used to build the feature matrices:

# %%
df_feat_top5 = df_feat.head(5)
predictors, _, df_eval = ap.predict_samples(
    list_df_feat={"all10": df_feat, "top5": df_feat_top5}, df_seq=df_seq, labels=labels,
    models=["rf", "svm"], n_cv=5, random_state=42, plot=False, n_jobs=1)

aa.display_df(df_eval, n_rows=10, show_shape=True)
# Out:
# DataFrame shape: (4, 17)
# <style type="text/css">
# #T_b5469 thead th {
#   background-color: white;
#   color: black;
# }
# #T_b5469 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_b5469 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_b5469 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_b5469  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_b5469" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5469_level0_col0" class="col_heading level0 col0" >feature_set</th>
#       <th id="T_b5469_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_b5469_level0_col2" class="col_heading level0 col2" >n_features</th>
#       <th id="T_b5469_level0_col3" class="col_heading level0 col3" >balanced_accuracy_mean</th>
# ...

# %% [markdown]
# **Toward explanation.** The ``is_shap_ready`` predictors (tree-based) can be handed to ``ap.explain_features`` for SHAP feature impact — the next step of the golden-pipeline spine. Here we list them:

# %%
shap_ready = df_eval[df_eval["is_shap_ready"]][["feature_set", "model"]]
aa.display_df(shap_ready, n_rows=10, show_shape=True)
# Out:
# DataFrame shape: (2, 2)
# <style type="text/css">
# #T_a6771 thead th {
#   background-color: white;
#   color: black;
# }
# #T_a6771 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_a6771 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_a6771 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_a6771  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_a6771" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6771_level0_col0" class="col_heading level0 col0" >feature_set</th>
#       <th id="T_a6771_level0_col1" class="col_heading level0 col1" >model</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6771_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a6771_row0_col0" class="data row0 col0" >all10</td>
# ...
