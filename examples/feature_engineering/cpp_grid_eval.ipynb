# %% [markdown]
# After :meth:`CPPGrid.run`, :meth:`CPPGrid.eval` scores every configuration and returns ``df_params`` joined to per-configuration quality columns (``avg_ABS_AUC`` is the mean of each feature table's ``abs_auc``), sorted best-first so ``df.iloc[0]`` is the best configuration.

# %%
import aaanalysis as aa
aa.options["verbose"] = False

df_seq = aa.load_dataset(name="DOM_GSEC", n=10)
labels = df_seq["label"].to_list()
grid = aa.CPPGrid(df_seq=df_seq, labels=labels, n_jobs=1, random_state=0)
grid.run(params_cpp={"n_filter": [10, 25]})
df_eval = grid.eval(sort_by="avg_ABS_AUC")
df_eval
# Out:
#    n_filter  df_scales  n_warnings  n_errors  avg_ABS_AUC  avg_abs_mean_dif  \
# 0        10          0           0         0       0.4680           0.23950
# 1        25          0           0         0       0.4548           0.21852
#
#    n_features
# 0          10
# 1          25

# %% [markdown]
# The best configuration's feature table is then ``grid.list_df_feat_[df_eval.index[0]]``.

# %%
best_i = df_eval.index[0]
grid.list_df_feat_[best_i].head()
# Out:
#                                       feature      category       subcategory  \
# 0        JMD_N_TMD_N-Segment(1,10)-ZIMJ680101      Polarity    Hydrophobicity
# 1  JMD_N_TMD_N-Pattern(C,2,5,8,12)-PALJ810110  Conformation           β-sheet
# 2          TMD-Pattern(N,1,5,8,11)-PALJ810110  Conformation           β-sheet
# 3    TMD_C_JMD_C-Pattern(N,4,8,12)-TANS770105  Conformation   β-turn (C-term)
# 4   TMD_C_JMD_C-Pattern(C,8,12,15)-AURR980102  Conformation  Linker (6-14 AA)
#
#                       scale_name  \
# 0                 Hydrophobicity
# 1                        β-sheet
# 2                        β-sheet
# 3           β-turn (3rd residue)
# 4  α-helix (N-terminal, outside)
#
#                                    scale_description  abs_auc  abs_mean_dif  \
# 0            Hydrophobicity (Zimmerman et al., 1968)    0.500         0.361
# 1  Normalized frequency of beta-sheet in all-beta...    0.470         0.233
# 2  Normalized frequency of beta-sheet in all-beta...    0.470         0.233
# 3  Normalized frequency of chain reversal S (Tana...    0.470         0.230
# 4  Normalized positional residue frequency at hel...    0.465         0.189
#
#    mean_dif  std_test  std_ref  p_val_mann_whitney  p_val_fdr_bh    positions
# 0     0.361     0.156    0.150            0.000157           1.0          1,2
# 1    -0.233     0.092    0.095            0.000381           1.0   9,13,16,19
# 2    -0.233     0.092    0.095            0.000381           1.0  11,15,18,21
# 3    -0.230     0.061    0.111            0.000381           1.0     24,28,32
# 4     0.189     0.054    0.099            0.000440           1.0     26,29,33

# %% [markdown]
# **Further parameters.** ``CPPGrid.eval`` also accepts: ``ascending`` — Sort direction.
