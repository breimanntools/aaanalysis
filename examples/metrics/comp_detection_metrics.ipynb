# %% [markdown]
# ``comp_detection_metrics`` pools per-residue predictions at a fixed score ``threshold`` and returns recall / precision / F1 / MCC (and the TP/FP/FN/TN counts) as a dict.

# %%
import numpy as np
import aaanalysis as aa

list_scores = [np.array([0.9, 0.1, 0.8, 0.2]), np.array([0.1, 0.9, 0.2, 0.7])]
list_positions = [[0, 2], [1, 3]]
aa.comp_detection_metrics(list_scores=list_scores, list_positions=list_positions,
                          threshold=0.5)
# Out:
# {'recall': 1.0,
#  'precision': 1.0,
#  'f1': 1.0,
#  'mcc': np.float64(1.0),
#  'tp': 4,
#  'fp': 0,
#  'fn': 0,
#  'tn': 4}

# %% [markdown]
# ``tolerance`` widens what counts as a hit: a predicted residue is a true positive when it lies within ``tolerance`` positions of a true site (default ``0`` = exact match). Relaxing it recovers near-miss predictions:

# %%
import pandas as pd
df_tol = pd.DataFrame(
    [aa.comp_detection_metrics(list_scores=list_scores, list_positions=list_positions,
                               threshold=0.5, tolerance=t) for t in [0, 1]],
    index=["tolerance=0", "tolerance=1"])
aa.display_df(df_tol)
# Out:
# <style type="text/css">
# #T_39fed thead th {
#   background-color: white;
#   color: black;
# }
# #T_39fed tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_39fed tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_39fed th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_39fed  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_39fed" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39fed_level0_col0" class="col_heading level0 col0" >recall</th>
#       <th id="T_39fed_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_39fed_level0_col2" class="col_heading level0 col2" >f1</th>
#       <th id="T_39fed_level0_col3" class="col_heading level0 col3" >mcc</th>
#       <th id="T_39fed_level0_col4" class="col_heading level0 col4" >tp</th>
#       <th id="T_39fed_level0_col5" class="col_heading level0 col5" >fp</th>
#       <th id="T_39fed_level0_col6" class="col_heading level0 col6" >fn</th>
#       <th id="T_39fed_level0_col7" class="col_heading level0 col7" >tn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39fed_level0_row0" class="row_heading level0 row0" >tolerance=0</th>
#       <td id="T_39fed_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_39fed_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_39fed_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_39fed_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_39fed_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_39fed_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_39fed_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_39fed_row0_col7" class="data row0 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_39fed_level0_row1" class="row_heading level0 row1" >tolerance=1</th>
#       <td id="T_39fed_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_39fed_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_39fed_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_39fed_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_39fed_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_39fed_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_39fed_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_39fed_row1_col7" class="data row1 col7" >4</td>
#     </tr>
#   </tbody>
# </table>
