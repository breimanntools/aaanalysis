# %% [markdown]
# :meth:`SeqMut.eval` tags each scanned mutation stable / disruptive by an ``|ΔCPP|`` threshold (default: the upper tertile) and summarizes disruptive rates per ``entry`` x ``region``.

# %%
import aaanalysis as aa
aa.options["verbose"] = False

df_seq = aa.load_dataset(name="DOM_GSEC", n=10)
labels = df_seq["label"].to_list()
sf = aa.SequenceFeature()
df_parts = sf.get_df_parts(df_seq=df_seq)
split_kws = sf.get_split_kws()
cpp = aa.CPP(df_parts=df_parts, split_kws=split_kws, verbose=False)
df_feat = cpp.run(labels=labels, n_filter=25)

seqmut = aa.SeqMut()
df_scan = seqmut.scan(df_seq=df_seq, df_feat=df_feat, region="tmd")
aa.display_df(seqmut.eval(df_scan=df_scan), n_rows=10, show_shape=True)
# Out:
# CPP using the Python kernel fallback — the compiled Cython extension is not available in this install. Output is bit-exact with the Cython path but ~2x slower. Reinstall via `pip install --force-reinstall aaanalysis` to fetch a prebuilt wheel.
# DataFrame shape: (20, 6)
# <style type="text/css">
# #T_fbdf2 thead th {
#   background-color: white;
#   color: black;
# }
# #T_fbdf2 tbody tr:nth-child(odd) {
#   background-color: #f2f2f2;
# }
# #T_fbdf2 tbody tr:nth-child(even) {
#   background-color: white;
# }
# #T_fbdf2 th {
#   padding: 5px;
#   white-space: nowrap;
# }
# #T_fbdf2  td {
#   padding: 5px;
#   white-space: nowrap;
# }
# </style>
# <table id="T_fbdf2" style='display:block; max-height: 300px; max-width: 100%; overflow-x: auto; overflow-y: auto;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbdf2_level0_col0" class="col_heading level0 col0" >entry</th>
#       <th id="T_fbdf2_level0_col1" class="col_heading level0 col1" >region</th>
#       <th id="T_fbdf2_level0_col2" class="col_heading level0 col2" >n_mut</th>
#       <th id="T_fbdf2_level0_col3" class="col_heading level0 col3" >n_disruptive</th>
#       <th id="T_fbdf2_level0_col4" class="col_heading level0 col4" >frac_disruptive</th>
#       <th id="T_fbdf2_level0_col5" class="col_heading level0 col5" >mean_delta_cpp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbdf2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fbdf2_row0_col0" class="data row0 col0" >P16070</td>
#       <td id="T_fbdf2_row0_col1" class="data row0 col1" >tmd</td>
#       <td id="T_fbdf2_row0_col2" class="data row0 col2" >437</td>
#       <td id="T_fbdf2_row0_col3" class="data row0 col3" >150</td>
#       <td id="T_fbdf2_row0_col4" class="data row0 col4" >0.343249</td>
#       <td id="T_fbdf2_row0_col5" class="data row0 col5" >0.251832</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fbdf2_row1_col0" class="data row1 col0" >P09803</td>
#       <td id="T_fbdf2_row1_col1" class="data row1 col1" >tmd</td>
#       <td id="T_fbdf2_row1_col2" class="data row1 col2" >437</td>
#       <td id="T_fbdf2_row1_col3" class="data row1 col3" >152</td>
#       <td id="T_fbdf2_row1_col4" class="data row1 col4" >0.347826</td>
#       <td id="T_fbdf2_row1_col5" class="data row1 col5" >0.195534</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_fbdf2_row2_col0" class="data row2 col0" >Q03157</td>
#       <td id="T_fbdf2_row2_col1" class="data row2 col1" >tmd</td>
#       <td id="T_fbdf2_row2_col2" class="data row2 col2" >437</td>
#       <td id="T_fbdf2_row2_col3" class="data row2 col3" >149</td>
#       <td id="T_fbdf2_row2_col4" class="data row2 col4" >0.340961</td>
#       <td id="T_fbdf2_row2_col5" class="data row2 col5" >0.200584</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fbdf2_row3_col0" class="data row3 col0" >P05556</td>
#       <td id="T_fbdf2_row3_col1" class="data row3 col1" >tmd</td>
#       <td id="T_fbdf2_row3_col2" class="data row3 col2" >437</td>
#       <td id="T_fbdf2_row3_col3" class="data row3 col3" >142</td>
#       <td id="T_fbdf2_row3_col4" class="data row3 col4" >0.324943</td>
#       <td id="T_fbdf2_row3_col5" class="data row3 col5" >0.265178</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_fbdf2_row4_col0" class="data row4 col0" >Q06481</td>
#       <td id="T_fbdf2_row4_col1" class="data row4 col1" >tmd</td>
#       <td id="T_fbdf2_row4_col2" class="data row4 col2" >437</td>
#       <td id="T_fbdf2_row4_col3" class="data row4 col3" >141</td>
#       <td id="T_fbdf2_row4_col4" class="data row4 col4" >0.322654</td>
#       <td id="T_fbdf2_row4_col5" class="data row4 col5" >0.191197</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_fbdf2_row5_col0" class="data row5 col0" >P05067</td>
#       <td id="T_fbdf2_row5_col1" class="data row5 col1" >tmd</td>
#       <td id="T_fbdf2_row5_col2" class="data row5 col2" >437</td>
#       <td id="T_fbdf2_row5_col3" class="data row5 col3" >147</td>
#       <td id="T_fbdf2_row5_col4" class="data row5 col4" >0.336384</td>
#       <td id="T_fbdf2_row5_col5" class="data row5 col5" >0.211840</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_fbdf2_row6_col0" class="data row6 col0" >P70180</td>
#       <td id="T_fbdf2_row6_col1" class="data row6 col1" >tmd</td>
#       <td id="T_fbdf2_row6_col2" class="data row6 col2" >437</td>
#       <td id="T_fbdf2_row6_col3" class="data row6 col3" >124</td>
#       <td id="T_fbdf2_row6_col4" class="data row6 col4" >0.283753</td>
#       <td id="T_fbdf2_row6_col5" class="data row6 col5" >0.201154</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_fbdf2_row7_col0" class="data row7 col0" >P01135</td>
#       <td id="T_fbdf2_row7_col1" class="data row7 col1" >tmd</td>
#       <td id="T_fbdf2_row7_col2" class="data row7 col2" >437</td>
#       <td id="T_fbdf2_row7_col3" class="data row7 col3" >147</td>
#       <td id="T_fbdf2_row7_col4" class="data row7 col4" >0.336384</td>
#       <td id="T_fbdf2_row7_col5" class="data row7 col5" >0.253857</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_fbdf2_row8_col0" class="data row8 col0" >P35070</td>
#       <td id="T_fbdf2_row8_col1" class="data row8 col1" >tmd</td>
#       <td id="T_fbdf2_row8_col2" class="data row8 col2" >437</td>
#       <td id="T_fbdf2_row8_col3" class="data row8 col3" >154</td>
#       <td id="T_fbdf2_row8_col4" class="data row8 col4" >0.352403</td>
#       <td id="T_fbdf2_row8_col5" class="data row8 col5" >0.213124</td>
#     </tr>
#     <tr>
#       <th id="T_fbdf2_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_fbdf2_row9_col0" class="data row9 col0" >P16234</td>
#       <td id="T_fbdf2_row9_col1" class="data row9 col1" >tmd</td>
#       <td id="T_fbdf2_row9_col2" class="data row9 col2" >437</td>
#       <td id="T_fbdf2_row9_col3" class="data row9 col3" >155</td>
#       <td id="T_fbdf2_row9_col4" class="data row9 col4" >0.354691</td>
#       <td id="T_fbdf2_row9_col5" class="data row9 col5" >0.218947</td>
#     </tr>
#   </tbody>
# </table>
